# %%
###QP_AiO example from Dr.Lakmali

using JuMP
import Juniper
import Ipopt

a = [2.5,-2.5,2,-2.5] # x-cordinates of selected circle
#a = [46.89,-2.5,2,-2.5]
#b = [34.21,0.25,-2.5,-2.25]
b = [0.3,0.25,-2.5,-2.25] # y-cordinates of selected circle
r = [2, 2, 2, 2 ] # Radius of selected cirlcles
NumVar = size(r)[1][1] 


function solveAiO( )

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, X)
    @variable(model, Y)
    @variable(model, R >= 0)

    @variable(model, x[i in 1:NumVar] )
    @variable(model, y[i in 1:NumVar] )
    @variable(model, z[i in 1:NumVar] >= 0)
  
    @objective(model, Max, R)
    @constraint( model, xeq[i in 1:NumVar], x[i] + X == a[i])
    @constraint( model, yeq[i in 1:NumVar], y[i] + Y == b[i])
    @constraint( model, zeq[i in 1:NumVar], z[i] + r[i] == R)

    @constraint( model, xyz[i in 1:NumVar], x[i]^2 + y[i]^2 >= z[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(X), value(Y), value(R)
end

function main()
    X, Y, R = solveAiO()
    @show(X)
    @show(Y)
    @show(R)
end
main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Max
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Incumbent using start values: 4.6835159429421
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 8.089999914169312
# Relaxation Obj: 4.6835159429421
# Obj: 4.6835159429421
# X = 0.00974954844341811
# Y = -0.6999552826453393
# R = 4.6835159429421
# 4.6835159429421

# %%
##QP_AiO for 4 selected circles in n=5, m=15 test case

using JuMP
import Juniper
import Ipopt

a = [2.5,-2.5,2,-2.5] # x-cordinates of selected circle
b = [0.3,0.25,-2.5,-2.25] # y-cordinates of selected circle
r = [2, 2, 2, 2 ] # Radius of selected cirlcles
NumVar = size(r)[1][1] 


function solveAiO( )

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, X)
    @variable(model, Y)
    @variable(model, R >= 0)

    @variable(model, x[i in 1:NumVar] )
    @variable(model, y[i in 1:NumVar] )
    @variable(model, z[i in 1:NumVar] >= 0)
  
    @objective(model, Min, R)
    @constraint( model, xeq[i in 1:NumVar], x[i] + X == a[i])
    @constraint( model, yeq[i in 1:NumVar], y[i] + Y == b[i])
    @constraint( model, zeq[i in 1:NumVar], z[i] + r[i] == R)

    @constraint( model, xyz[i in 1:NumVar], x[i]^2 + y[i]^2 <= z[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(X), value(Y), value(R)
end

function main()
    X, Y, R = solveAiO()
    @show(X)
    @show(Y)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 4.806354399951325
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.16699981689453125
# Relaxation Obj: 4.806354399951325
# Obj: 4.806354399951325
# X = -1.0456187885555454e-7
# Y = -0.9749997949767099
# R = 4.806354399951325
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 4.806354399951325
# Status of relaxation: LOCALLY_SOLVED
# ...

# %%
##QP_AiO for 4 selected circles in n=10, m=25 test case

using JuMP
import Juniper
import Ipopt

a = [46.89, 18.36, 24.81, 14.31, 45.81] # x-cordinates of selected circle
b = [34.21, 34.21, 15.03, 5.03, 17.23] # y-cordinates of selected circle
r = [20, 20, 20, 20, 20 ] # Radius of selected circles
NumVar = size(r)[1][1] 


function solveAiO( )

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, X)
    @variable(model, Y)
    @variable(model, R >= 0)

    @variable(model, x[i in 1:NumVar] )
    @variable(model, y[i in 1:NumVar] )
    @variable(model, z[i in 1:NumVar] >= 0)
  
    @objective(model, Min, R)
    @constraint( model, xeq[i in 1:NumVar], x[i] + X == a[i])
    @constraint( model, yeq[i in 1:NumVar], y[i] + Y == b[i])
    @constraint( model, zeq[i in 1:NumVar], z[i] + r[i] == R)

    @constraint( model, xyz[i in 1:NumVar], x[i]^2 + y[i]^2 <= z[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(X), value(Y), value(R)
end

function main()
    X, Y, R = solveAiO()
    @show(X)
    @show(Y)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 18
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 41.868520759503134
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.13299989700317383
# Relaxation Obj: 41.868520759503134
# Obj: 41.868520759503134
# X = 30.599999991460297
# Y = 19.62000000953417
# R = 41.868520759503134
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 18
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 41.868520759503134
# Status of relaxation: LOCALLY_SOLVED
# ...

# %%
##QP_AiO for 4 selected circles in n=10, m=50 test case

using JuMP
import Juniper
import Ipopt

a = [13.239512466541303, 5.513695828127543, 41.55335924184264, 43.70990076229758] # x-cordinates of selected circle
b = [43.945805488954605, 14.997506943080591, 31.204816928920724, 15.106911655793608] # y-cordinates of selected circle
r = [20, 20, 20, 20 ] # Radius of selected cirlcles
   
NumVar = size(r)[1][1] 


function solveAiO( )

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, X)
    @variable(model, Y)
    @variable(model, R >= 0)

    @variable(model, x[i in 1:NumVar] )
    @variable(model, y[i in 1:NumVar] )
    @variable(model, z[i in 1:NumVar] >= 0)
  
    @objective(model, Min, R)
    @constraint( model, xeq[i in 1:NumVar], x[i] + X == a[i])
    @constraint( model, yeq[i in 1:NumVar], y[i] + Y == b[i])
    @constraint( model, zeq[i in 1:NumVar], z[i] + r[i] == R)

    @constraint( model, xyz[i in 1:NumVar], x[i]^2 + y[i]^2 <= z[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(X), value(Y), value(R)
end

function main()
    X, Y, R = solveAiO()
    @show(X)
    @show(Y)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 41.7278379893865
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.0819997787475586
# Relaxation Obj: 41.7278379893865
# Obj: 41.7278379893865
# X = 24.58212046374567
# Y = 25.41355826361457
# R = 41.7278379893865
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 41.7278379893865
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.08299994468688965
# ...

# %%
##QP_AiO for 4 selected circles in n=10, m=100 test case

using JuMP
import Juniper
import Ipopt

a = [13.239512466541303, 41.55335924184264, 43.70990076229758, 13.150886893355297] # x-cordinates of selected circle
b = [43.945805488954605, 31.204816928920724, 15.106911655793608, 11.789181775998983] # y-cordinates of selected circle
r = [20, 20, 20, 20 ] # Radius of selected cirlcles
   
   
NumVar = size(r)[1][1] 


function solveAiO( )

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, X)
    @variable(model, Y)
    @variable(model, R >= 0)

    @variable(model, x[i in 1:NumVar] )
    @variable(model, y[i in 1:NumVar] )
    @variable(model, z[i in 1:NumVar] >= 0)
  
    @objective(model, Min, R)
    @constraint( model, xeq[i in 1:NumVar], x[i] + X == a[i])
    @constraint( model, yeq[i in 1:NumVar], y[i] + Y == b[i])
    @constraint( model, zeq[i in 1:NumVar], z[i] + r[i] == R)

    @constraint( model, xyz[i in 1:NumVar], x[i]^2 + y[i]^2 <= z[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(X), value(Y), value(R)
end

function main()
    X, Y, R = solveAiO()
    @show(X)
    @show(Y)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 41.1065909982292
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.13200020790100098
# Relaxation Obj: 41.1065909982292
# Obj: 41.1065909982292
# X = 26.868995309890536
# Y = 27.829807823090338
# R = 41.1065909982292
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 41.1065909982292
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.13300013542175293
# ...

# %%
##QP_AiO for 4 selected circles in n=20, m=25 test case

using JuMP
import Juniper
import Ipopt

a = [49.42043424128368, 31.611086580497098,  12.419857083265606] # x-cordinates of selected circle
b = [ 44.79128960675432, 19.19929956530496, 28.300299268064713] # y-cordinates of selected circle
r = [20, 20, 20 ] # Radius of selected cirlcles
   
NumVar = size(r)[1][1] 


function solveAiO( )

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, X)
    @variable(model, Y)
    @variable(model, R >= 0)

    @variable(model, x[i in 1:NumVar] )
    @variable(model, y[i in 1:NumVar] )
    @variable(model, z[i in 1:NumVar] >= 0)
  
    @objective(model, Min, R)
    @constraint( model, xeq[i in 1:NumVar], x[i] + X == a[i])
    @constraint( model, yeq[i in 1:NumVar], y[i] + Y == b[i])
    @constraint( model, zeq[i in 1:NumVar], z[i] + r[i] == R)

    @constraint( model, xyz[i in 1:NumVar], x[i]^2 + y[i]^2 <= z[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(X), value(Y), value(R)
end

function main()
    X, Y, R = solveAiO()
    @show(X)
    @show(Y)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 12
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 40.254601163366
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.0989999771118164
# Relaxation Obj: 40.254601163366
# Obj: 40.254601163366
# X = 30.920145668409557
# Y = 36.54579442364673
# R = 40.254601163366
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 12
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 40.254601163366
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.04999995231628418
# ...

# %%
##QP_AiO for 4 selected circles in n=20, m=50 test case

using JuMP
import Juniper
import Ipopt

a = [8.952575686584531, 46.74153578924209, 32.34771758225827, 11.355837839937607] # x-cordinates of selected circle
b = [38.87977889206978, 23.45904720270292, 37.565559688461505, 13.734380115583644] # y-cordinates of selected circle
r = [20, 20, 20, 20 ] # Radius of selected circles
   
NumVar = size(r)[1][1] 


function solveAiO( )

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, X)
    @variable(model, Y)
    @variable(model, R >= 0)

    @variable(model, x[i in 1:NumVar] )
    @variable(model, y[i in 1:NumVar] )
    @variable(model, z[i in 1:NumVar] >= 0)
  
    @objective(model, Min, R)
    @constraint( model, xeq[i in 1:NumVar], x[i] + X == a[i])
    @constraint( model, yeq[i in 1:NumVar], y[i] + Y == b[i])
    @constraint( model, zeq[i in 1:NumVar], z[i] + r[i] == R)

    @constraint( model, xyz[i in 1:NumVar], x[i]^2 + y[i]^2 <= z[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(X), value(Y), value(R)
end

function main()
    X, Y, R = solveAiO()
    @show(X)
    @show(Y)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 40.71605633426372
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.23200011253356934
# Relaxation Obj: 40.71605633426372
# Obj: 40.71605633426372
# X = 26.50038624217553
# Y = 27.86935953170211
# R = 40.71605633426372
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 40.71605633426372
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.16699981689453125
# ...

# %%
##QP_AiO for 4 selected circles in n=20, m=100 test case

using JuMP
import Juniper
import Ipopt

a = [31.638687927784943,1.6854696772411517, 34.96903642134066, 7.147231577211446] # x-cordinates of selected circle
b = [17.17851430439765, 2.8765182589078004, 39.17787190718997, 33.785980366613536] # y-cordinates of selected circle
r = [20, 20, 20, 20 ] # Radius of selected circles
   
NumVar = size(r)[1][1] 


function solveAiO( )

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, X)
    @variable(model, Y)
    @variable(model, R >= 0)

    @variable(model, x[i in 1:NumVar] )
    @variable(model, y[i in 1:NumVar] )
    @variable(model, z[i in 1:NumVar] >= 0)
  
    @objective(model, Min, R)
    @constraint( model, xeq[i in 1:NumVar], x[i] + X == a[i])
    @constraint( model, yeq[i in 1:NumVar], y[i] + Y == b[i])
    @constraint( model, zeq[i in 1:NumVar], z[i] + r[i] == R)

    @constraint( model, xyz[i in 1:NumVar], x[i]^2 + y[i]^2 <= z[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(X), value(Y), value(R)
end

function main()
    X, Y, R = solveAiO()
    @show(X)
    @show(Y)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 44.62510960814807
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.14499998092651367
# Relaxation Obj: 44.62510960814807
# Obj: 44.62510960814807
# X = 18.327253047203637
# Y = 21.027195084962255
# R = 44.62510960814807
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 15
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 44.62510960814807
# Status of relaxation: LOCALLY_SOLVED
# ...

# %%
##QP_AiO for 22 selected circles in n=22, m=25 test case

using JuMP
import Juniper
import Ipopt

n=22
len=50
using Random
Random.seed!(12)
using Distributions
a=rand(Uniform(1,len),n) #RANDOMLY GENERATED X VALUES FOR CENTER
b=rand(Uniform(1,len),n) #RANDOMLY GENERATED Y VALUES FOR CENTER
#r= rand(Uniform(20, len), n ) # RANDOMLY GENERATED RADIUS VALUES

r= [15, 15 , 15 , 15 ,15, 15, 15 , 15 , 15 ,15 ,15, 15 , 15 , 15 ,15 , 15, 15 , 15 , 15 ,15 , 15 , 15] # Radiuus of circle
   
NumVar = size(r)[1][1] 


function solveAiO( )

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, X)
    @variable(model, Y)
    @variable(model, R >= 0)

    @variable(model, x[i in 1:NumVar] )
    @variable(model, y[i in 1:NumVar] )
    @variable(model, z[i in 1:NumVar] >= 0)
  
    @objective(model, Min, R)
    @constraint( model, xeq[i in 1:NumVar], x[i] + X == a[i])
    @constraint( model, yeq[i in 1:NumVar], y[i] + Y == b[i])
    @constraint( model, zeq[i in 1:NumVar], z[i] + r[i] == R)

    @constraint( model, xyz[i in 1:NumVar], x[i]^2 + y[i]^2 <= z[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(X), value(Y), value(R)
end

function main()
    X, Y, R = solveAiO()
    @show(X)
    @show(Y)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 69
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 42.29932110234531
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.2650001049041748
# Relaxation Obj: 42.29932110234531
# Obj: 42.29932110234531
# X = 25.147230543083026
# Y = 25.220841082831544
# R = 42.29932110234531
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 69
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: 42.29932110234531
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.2669999599456787
# ...
