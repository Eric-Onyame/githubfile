# %%
# THIS IS THE QUADRATIC APPROACH OF ALGORITHM ONE FOR 5 CIRCLES AND 15 CUSTOMERS AFTER 4 CIRCLES WERE SELECTED FROM 5


using JuMP
import Juniper
import Ipopt
using CPUTime
using Dates
import Dates
 NumVar = 4
    a = [2.5,-2.5,2,-2.5] # x-cordinates of selected circle
    b = [0.3,0.25,-2.5,-2.25] # y-cordinates of selected circle
    r = [2, 2, 2, 2 ] # Radius of selected cirlcles
    

#Dates package
#tb=time() #, te=time(), time=te-tb

function inner_loop( R)

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, x >= 0)
    @variable(model, y >= 0)
    @variable(model, z >= 0)
  
    @objective(model, Min, x^2 + y^2 - z)
    @constraint(
        model, 
        [i in 1:NumVar],
        -2 * x * a[i] - 2 * b[i] * y + z <= (R - r[i])^2 - a[i]^2 - b[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
    count=0;
    x, y, z, R = 0.0, 0.0, Inf,0
    while abs(x^2 + y^2 - z) >= 0.01
	R = 0.0 ### Added this line
        for i in 1:length(a)
            R = max(R, sqrt((a[i] - x)^2 + (b[i] - y)^2) + r[i])
        end
        x, y, z = inner_loop(R)
        count=count+1;
        @show(count)
        println("The abs value is: abs(x^2+y^2-z) = " , abs(x^2+y^2-z))
    end
    @show(x)
   
    @show(y)
    @show(z)
    @show(R)
    
    
end
main()
@time main()
# te=time()
#   time=te-tb
#  println(time)
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -1.0246749516686935e-7
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.1659998893737793
# Relaxation Obj: -1.0246749516686935e-7
# Obj: -1.0246749516686935e-7
# count = 1
# The abs value is: abs(x^2+y^2-z) = 1.0246749516686936e-7
# x = -9.83098052638232e-9
# y = -9.812275979479342e-9
# z = 1.024674953597983e-7
# R = 5.3634060117684275
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# ...

# %%
# THIS IS THE QUADRATIC APPROACH OF ALGORITHM ONE FOR 10 CIRCLES AND 25 CUSTOMERS AFTER 5 CIRCLES WERE SELECTED FROM 10


using JuMP
import Juniper
import Ipopt
 NumVar = 5
    a = [46.89, 18.36, 24.81, 14.31, 45.81] # x-cordinates of selected circle
    b = [34.21, 34.21, 15.03, 5.03, 17.23] # y-cordinates of selected circle
    r = [20, 20, 20, 20, 20 ] # Radius of selected circles
    
function inner_loop( R)

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, x >= 0)
    @variable(model, y >= 0)
    @variable(model, z >= 0)
  
    @objective(model, Min, x^2 + y^2 - z)
    @constraint(
        model, 
        [i in 1:NumVar],
        -2 * x * a[i] - 2 * b[i] * y + z <= (R - r[i])^2 - a[i]^2 - b[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
    count=0;
    x, y, z, R = 0.0, 0.0, Inf,0
    while abs(x^2 + y^2 - z) >= 0.01
	R = 0.0 ### Added this line
        for i in 1:length(a)
            R = max(R, sqrt((a[i] - x)^2 + (b[i] - y)^2) + r[i])
        end
        x, y, z = inner_loop(R)
        count=count+1;
        @show(count)
        println("The abs value is: abs(x^2+y^2-z) = " , abs(x^2+y^2-z))
    end
    @show(x)
    @show(y)
    @show(z)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -2890.7640156945854
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.2669999599456787
# Relaxation Obj: -2890.7640156945854
# Obj: -2890.7640156945854
# count = 1
# The abs value is: abs(x^2+y^2-z) = 2890.7640156945854
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -3.137917997264594e-5
# Status of relaxation: LOCALLY_SOLVED
# ...

# %%
# THIS IS THE QUADRATIC APPROACH OF ALGORITHM ONE FOR 10 CIRCLES AND 50 CUSTOMERS AFTER 4 CIRCLES WERE SELECTED FROM 10


using JuMP
import Juniper
import Ipopt
 NumVar = 4
    a = [13.239512466541303, 5.513695828127543, 41.55335924184264, 43.70990076229758] # x-cordinates of selected circle
    b = [43.945805488954605, 14.997506943080591, 31.204816928920724, 15.106911655793608] # y-cordinates of selected circle
    r = [20, 20, 20, 20 ] # Radius of selected cirlcles
   

function inner_loop( R)

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, x >= 0)
    @variable(model, y >= 0)
    @variable(model, z >= 0)
  
    @objective(model, Min, x^2 + y^2 - z)
    @constraint(
        model, 
        [i in 1:NumVar],
        -2 * x * a[i] - 2 * b[i] * y + z <= (R - r[i])^2 - a[i]^2 - b[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
    count=0;
    x, y, z, R = 0.0, 0.0, Inf,0
    while abs(x^2 + y^2 - z) >= 0.01
	R = 0.0 ### Added this line
        for i in 1:length(a)
            R = max(R, sqrt((a[i] - x)^2 + (b[i] - y)^2) + r[i])
        end
        x, y, z = inner_loop(R)
        count=count+1;
        @show(count)
        println("The abs value is: abs(x^2+y^2-z) = " , abs(x^2+y^2-z))
    end
    @show(x)
    @show(y)
    @show(z)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -2228.323330246985
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.11599993705749512
# Relaxation Obj: -2228.323330246985
# Obj: -2228.323330246985
# count = 1
# The abs value is: abs(x^2+y^2-z) = 2228.323330246985
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -2.8090905175304215e-5
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.06599998474121094
# ...

# %%
# THIS IS THE QUADRATIC APPROACH OF ALGORITHM ONE FOR 10 CIRCLES AND 100 CUSTOMERS AFTER 4 CIRCLES WERE SELECTED FROM 10


using JuMP
import Juniper
import Ipopt
 NumVar = 4
    a = [13.239512466541303, 41.55335924184264, 43.70990076229758, 13.150886893355297] # x-cordinates of selected circle
    b = [43.945805488954605, 31.204816928920724, 15.106911655793608, 11.789181775998983] # y-cordinates of selected circle
    r = [20, 20, 20, 20 ] # Radius of selected cirlcles
   

function inner_loop( R)

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, x >= 0)
    @variable(model, y >= 0)
    @variable(model, z >= 0)
  
    @objective(model, Min, x^2 + y^2 - z)
    @constraint(
        model, 
        [i in 1:NumVar],
        -2 * x * a[i] - 2 * b[i] * y + z <= (R - r[i])^2 - a[i]^2 - b[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
    count=0;
    x, y, z, R = 0.0, 0.0, Inf,0
    while abs(x^2 + y^2 - z) >= 0.01
	R = 0.0 ### Added this line
        for i in 1:length(a)
            R = max(R, sqrt((a[i] - x)^2 + (b[i] - y)^2) + r[i])
        end
        x, y, z = inner_loop(R)
        count=count+1;
        @show(count)
        println("The abs value is: abs(x^2+y^2-z) = " , abs(x^2+y^2-z))
    end
    @show(x)
    @show(y)
    @show(z)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -2254.934088167439
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.059999942779541016
# Relaxation Obj: -2254.934088167439
# Obj: -2254.934088167439
# count = 1
# The abs value is: abs(x^2+y^2-z) = 2254.934088167439
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -3.150574605115253e-5
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.12199997901916504
# ...

# %%
# THIS IS THE QUADRATIC APPROACH OF ALGORITHM ONE FOR 20 CIRCLES AND 25 CUSTOMERS AFTER 3 CIRCLES WERE SELECTED FROM 10


using JuMP
import Juniper
import Ipopt
 NumVar = 3
    a = [49.42043424128368, 31.611086580497098,  12.419857083265606] # x-cordinates of selected circle
    b = [ 44.79128960675432, 19.19929956530496, 28.300299268064713] # y-cordinates of selected circle
    r = [20, 20, 20 ] # Radius of selected cirlcles
   

function inner_loop( R)

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, x >= 0)
    @variable(model, y >= 0)
    @variable(model, z >= 0)
  
    @objective(model, Min, x^2 + y^2 - z)
    @constraint(
        model, 
        [i in 1:NumVar],
        -2 * x * a[i] - 2 * b[i] * y + z <= (R - r[i])^2 - a[i]^2 - b[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
    count=0;
    x, y, z, R = 0.0, 0.0, Inf,0
    while abs(x^2 + y^2 - z) >= 0.01
	R = 0.0 ### Added this line
        for i in 1:length(a)
            R = max(R, sqrt((a[i] - x)^2 + (b[i] - y)^2) + r[i])
        end
        x, y, z = inner_loop(R)
        count=count+1;
        @show(count)
        println("The abs value is: abs(x^2+y^2-z) = " , abs(x^2+y^2-z))
    end
    @show(x)
    @show(y)
    @show(z)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -4038.390094606265
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.08299994468688965
# Relaxation Obj: -4038.390094606265
# Obj: -4038.390094606265
# count = 1
# The abs value is: abs(x^2+y^2-z) = 4038.390094606265
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -4.0373888850808726e-5
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.03299999237060547
# ...

# %%
# THIS IS THE QUADRATIC APPROACH OF ALGORITHM ONE FOR 20 CIRCLES AND 50 CUSTOMERS AFTER 4 CIRCLES WERE SELECTED FROM 10


using JuMP
import Juniper
import Ipopt
 NumVar = 4
    a = [8.952575686584531, 46.74153578924209, 32.34771758225827, 11.355837839937607] # x-cordinates of selected circle
    b = [38.87977889206978, 23.45904720270292, 37.565559688461505, 13.734380115583644] # y-cordinates of selected circle
    r = [20, 20, 20, 20 ] # Radius of selected circles
   

function inner_loop( R)

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, x >= 0)
    @variable(model, y >= 0)
    @variable(model, z >= 0)
  
    @objective(model, Min, x^2 + y^2 - z)
    @constraint(
        model, 
        [i in 1:NumVar],
        -2 * x * a[i] - 2 * b[i] * y + z <= (R - r[i])^2 - a[i]^2 - b[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
    count=0;
    x, y, z, R = 0.0, 0.0, Inf,0
    while abs(x^2 + y^2 - z) >= 0.01
	R = 0.0 ### Added this line
        for i in 1:length(a)
            R = max(R, sqrt((a[i] - x)^2 + (b[i] - y)^2) + r[i])
        end
        x, y, z = inner_loop(R)
        count=count+1;
        @show(count)
        println("The abs value is: abs(x^2+y^2-z) = " , abs(x^2+y^2-z))
    end
    @show(x)
    @show(y)
    @show(z)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -2305.9430821193723
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.015999794006347656
# Relaxation Obj: -2305.9430821193723
# Obj: -2305.9430821193723
# count = 1
# The abs value is: abs(x^2+y^2-z) = 2305.9430821193723
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -3.103029416706704e-5
# Status of relaxation: LOCALLY_SOLVED
# ...

# %%
# THIS IS THE QUADRATIC APPROACH OF ALGORITHM ONE FOR 20 CIRCLES AND 100 CUSTOMERS AFTER 4 CIRCLES WERE SELECTED FROM 10


using JuMP
import Juniper
import Ipopt
 NumVar = 4
    a = [31.638687927784943,1.6854696772411517, 34.96903642134066, 7.147231577211446] # x-cordinates of selected circle
    b = [17.17851430439765, 2.8765182589078004, 39.17787190718997, 33.785980366613536] # y-cordinates of selected circle
    r = [20, 20, 20, 20 ] # Radius of selected circles
   

function inner_loop( R)

  model = Model(
        optimizer_with_attributes(
            Juniper.Optimizer,
            "nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
                MOI.Silent() => true,
            ),
        ),
    )

    @variable(model, x >= 0)
    @variable(model, y >= 0)
    @variable(model, z >= 0)
  
    @objective(model, Min, x^2 + y^2 - z)
    @constraint(
        model, 
        [i in 1:NumVar],
        -2 * x * a[i] - 2 * b[i] * y + z <= (R - r[i])^2 - a[i]^2 - b[i]^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
    count=0;
    x, y, z, R = 0.0, 0.0, Inf,0
    while abs(x^2 + y^2 - z) >= 0.01
	R = 0.0 ### Added this line
        for i in 1:length(a)
            R = max(R, sqrt((a[i] - x)^2 + (b[i] - y)^2) + r[i])
        end
        x, y, z = inner_loop(R)
        count=count+1;
        @show(count)
        println("The abs value is: abs(x^2+y^2-z) = " , abs(x^2+y^2-z))
    end
    @show(x)
    @show(y)
    @show(z)
    @show(R)
end
main()
@time main()
# Out:
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -2151.3431461697
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.016000032424926758
# Relaxation Obj: -2151.3431461697
# Obj: -2151.3431461697
# count = 1
# The abs value is: abs(x^2+y^2-z) = 2151.3431461696996
# nl_solver         : MathOptInterface.OptimizerWithAttributes(Ipopt.Optimizer, Pair{MathOptInterface.AbstractOptimizerAttribute, Any}[MathOptInterface.Silent() => true])
# feasibility_pump  : false
# log_levels        : [:Options, :Table, :Info]
#
# #Variables: 3
# #IntBinVar: 0
# Obj Sense: Min
#
# Incumbent using start values: -2.7456227826405666e-5
# Status of relaxation: LOCALLY_SOLVED
# Time for relaxation: 0.06599998474121094
# ...

# %%
# Out:
#     Updating registry at `C:\Users\ERIC ONYAME\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed CPUTime ─ v1.0.0
#     Updating `C:\Users\ERIC ONYAME\.julia\environments\v1.7\Project.toml`
#   [a9c8d775] + CPUTime v1.0.0
#     Updating `C:\Users\ERIC ONYAME\.julia\environments\v1.7\Manifest.toml`
#   [a9c8d775] + CPUTime v1.0.0
# Precompiling project...
#   ✓ CPUTime
#   1 dependency successfully precompiled in 11 seconds (246 already precompiled, 3 skipped during auto due to previous errors)
