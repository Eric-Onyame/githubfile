# %%
using JuMP
using Printf
import Juniper
import Ipopt

a = [2.5,-2.5,2,-2.5] # x-cordinates of selected circle
b = [0.3,0.25,-2.5,-2.25] # y-cordinates of selected circle
r = [2, 2, 2, 2 ] # Radius of selected cirlcles

NumVar = size(r)[1] 

rho = 1.0  ### Augmented Lagrangian penalty coefficient
  ## Note: rho may be allowed to vary under restriction


## Typing of parameters is optional, but wise.
## Form the AL primal subproblem
function solveSP(i::Int64, vdual::Dict{String,Float64}, X::Float64,Y::Float64, R::Float64 )

  model = Model(
        optimizer_with_attributes(
            #Juniper.Optimizer,
            #"nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
            #    MOI.Silent() => true,
            #),
        ),
    )
    set_optimizer_attribute(model, "print_level", 0)  ### Suppress Ipopt output
    set_optimizer_attribute(model, "tol", 1e-14)  ### Not required in general

    @variable(model, x )
    @variable(model, y )
    @variable(model, z >= 0)
  
    ### primal objective + Lagrange terms + augmented (squared penalty) terms
    @objective(model, Min, z+r[i] 
	+ vdual["x"]*(x + X - a[i]) + vdual["y"]*(y + Y - b[i]) + vdual["z"]*(z + r[i] - R)
	+ 0.5*rho*( (x+X-a[i])^2 + (y+Y-b[i])^2 + (z+r[i]-R)^2 ) )

    ### All coupling constraints are relaxed.
    @constraint( model, xyz, x^2 + y^2 <= z^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
  ## Initialization
    x = Dict{Int64,Float64}()
    y = Dict{Int64,Float64}()
    z = Dict{Int64,Float64}()

    ### Initialize Lagrangian multipliers to zero value
    vdual = Dict{Int64, Dict{String,Float64}}()
    for i in 1:NumVar
	vdual[i] = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    end

    X,Y,R=0.0,0.0,0.0
    oldX,oldY,oldR=0.0,0.0,0.0
    ### Initialize R to average of r[i], i=1,...,n
    for i in 1:length(a)
	R += (1.0/NumVar)*(r[i])
    end
  ## End of initialization

for n in 1:1000
    ### Solve AL subproblem for each subproblem i with X,Y,R fixed
    for i in 1:NumVar
      x[i],y[i],z[i] = solveSP(i,vdual[i],X,Y,R)
    end

    ### Subproblems in X,Y,R (with x,y,z fixed) can be solved in closed-form
    oldX,oldY,oldR=X,Y,R
    X,Y,R=0.0,0.0,0.0
    for i in 1:NumVar
	X += (1.0/NumVar)*(a[i]-x[i])
	Y += (1.0/NumVar)*(b[i]-y[i])
	R += (1.0/NumVar)*(z[i]+r[i])
    end

    ### Update Lagrange multipliers, compute a measure of primal infeasibility.
    discr = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    for i in 1:NumVar
	vdual[i]["x"] += rho*(x[i] + X - a[i]) 
	vdual[i]["y"] += rho*(y[i] + Y - b[i]) 
	vdual[i]["z"] += rho*(z[i] + r[i] - R)

	discr["x"] += abs(x[i] + X - a[i])
	discr["y"] += abs(y[i] + Y - b[i])
	discr["z"] += abs(z[i] + r[i] - R)
    end
    @printf("Iter %d Primal Discrepancies %8.8f R value %8.8f\n", 
	n, discr["x"] + discr["y"] + discr["z"], R)
    d_discr = abs(X-oldX)+abs(Y-oldY)+abs(R-oldR) ### Dual residues
    if discr["x"] + discr["y"] + discr["z"] + d_discr < 1e-7
	println("Stopping at iteration ",n)  ### Primal feasible within tolerance
	break
    end
end
    @show(X)
    @show(Y)
    @show(R)

println("Correct values are: ")
    
println("X = ",-1.0456187885555454e-7)
println("Y = ",-0.9749997949767099)
println("R = ",4.806354399951325)
end

main()
# Out:
# Iter 1 Primal Discrepancies 10.67947466 R value 2.94942158
# Iter 2 Primal Discrepancies 3.07165476 R value 4.26249368
# Iter 3 Primal Discrepancies 2.58813419 R value 5.14531200
# Iter 4 Primal Discrepancies 3.74587354 R value 5.37591350
# Iter 5 Primal Discrepancies 2.57022246 R value 5.16629049
# Iter 6 Primal Discrepancies 0.78953482 R value 4.84267703
# Iter 7 Primal Discrepancies 0.71916549 R value 4.62508178
# Iter 8 Primal Discrepancies 1.02607066 R value 4.56982153
# Iter 9 Primal Discrepancies 0.73936137 R value 4.62338513
# Iter 10 Primal Discrepancies 0.36149338 R value 4.70468649
# Iter 11 Primal Discrepancies 0.36266554 R value 4.75962469
# Iter 12 Primal Discrepancies 0.37986607 R value 4.77455470
# Iter 13 Primal Discrepancies 0.35949552 R value 4.76268308
# Iter 14 Primal Discrepancies 0.35246401 R value 4.74384374
# Iter 15 Primal Discrepancies 0.35068271 R value 4.73116899
# Iter 16 Primal Discrepancies 0.35075186 R value 4.72790603
# Iter 17 Primal Discrepancies 0.35188219 R value 4.73084141
# Iter 18 Primal Discrepancies 0.35322528 R value 4.73523700
# Iter 19 Primal Discrepancies 0.35426819 R value 4.73801589
# Iter 20 Primal Discrepancies 0.35487468 R value 4.73848535
# Iter 21 Primal Discrepancies 0.35514252 R value 4.73748581
# Iter 22 Primal Discrepancies 0.35523561 R value 4.73619399
# Iter 23 Primal Discrepancies 0.31289890 R value 4.73976127
# Iter 24 Primal Discrepancies 0.24628466 R value 4.75074669
# Iter 25 Primal Discrepancies 0.20165978 R value 4.76431697
# Iter 26 Primal Discrepancies 0.16744258 R value 4.77651864
# Iter 27 Primal Discrepancies 0.15642350 R value 4.78523693
# Iter 28 Primal Discrepancies 0.14559247 R value 4.79012713
# Iter 29 Primal Discrepancies 0.12679303 R value 4.79200960
# Iter 30 Primal Discrepancies 0.10450933 R value 4.79216798
# Iter 31 Primal Discrepancies 0.08486458 R value 4.79181383
# Iter 32 Primal Discrepancies 0.07304827 R value 4.79179964
# Iter 33 Primal Discrepancies 0.06757731 R value 4.79254477
# Iter 34 Primal Discrepancies 0.04091514 R value 4.79634934
# Iter 35 Primal Discrepancies 0.02320728 R value 4.80170523
# Iter 36 Primal Discrepancies 0.01676157 R value 4.80688520
# Iter 37 Primal Discrepancies 0.02067804 R value 4.81063788
# Iter 38 Primal Discrepancies 0.02185014 R value 4.81238173
# Iter 39 Primal Discrepancies 0.01955067 R value 4.81218289
# Iter 40 Primal Discrepancies 0.01418881 R value 4.81057669
# Iter 41 Primal Discrepancies 0.00798102 R value 4.80831650
# Iter 42 Primal Discrepancies 0.00579262 R value 4.80613084
# Iter 43 Primal Discrepancies 0.00816721 R value 4.80454749
# Iter 44 Primal Discrepancies 0.00891365 R value 4.80381171
# Iter 45 Primal Discrepancies 0.00803497 R value 4.80389555
# Iter 46 Primal Discrepancies 0.00578521 R value 4.80457314
# Iter 47 Primal Discrepancies 0.00347253 R value 4.80552664
# Iter 48 Primal Discrepancies 0.00259157 R value 4.80644871
# Iter 49 Primal Discrepancies 0.00349735 R value 4.80711669
# Iter 50 Primal Discrepancies 0.00379702 R value 4.80742709
# Iter 51 Primal Discrepancies 0.00341560 R value 4.80739172
# Iter 52 Primal Discrepancies 0.00242229 R value 4.80710586
# Iter 53 Primal Discrepancies 0.00145205 R value 4.80670360
# Iter 54 Primal Discrepancies 0.00107509 R value 4.80631460
# Iter 55 Primal Discrepancies 0.00146901 R value 4.80603280
# Iter 56 Primal Discrepancies 0.00159734 R value 4.80590185
# Iter 57 Primal Discrepancies 0.00143777 R value 4.80591677
# Iter 58 Primal Discrepancies 0.00102415 R value 4.80603737
# Iter 59 Primal Discrepancies 0.00061416 R value 4.80620707
# Iter 60 Primal Discrepancies 0.00045578 R value 4.80637118
# Iter 61 Primal Discrepancies 0.00062053 R value 4.80649007
# Iter 62 Primal Discrepancies 0.00067443 R value 4.80654531
# Iter 63 Primal Discrepancies 0.00060695 R value 4.80653902
# Iter 64 Primal Discrepancies 0.00043179 R value 4.80648814
# Iter 65 Primal Discrepancies 0.00025891 R value 4.80641655
# Iter 66 Primal Discrepancies 0.00019201 R value 4.80634731
# Iter 67 Primal Discrepancies 0.00026169 R value 4.80629716
# Iter 68 Primal Discrepancies 0.00028446 R value 4.80627385
# Iter 69 Primal Discrepancies 0.00025601 R value 4.80627651
# Iter 70 Primal Discrepancies 0.00018219 R value 4.80629797
# Iter 71 Primal Discrepancies 0.00010925 R value 4.80632817
# Iter 72 Primal Discrepancies 0.00008104 R value 4.80635738
# Iter 73 Primal Discrepancies 0.00011041 R value 4.80637854
# Iter 74 Primal Discrepancies 0.00012001 R value 4.80638837
# Iter 75 Primal Discrepancies 0.00010801 R value 4.80638725
# Iter 76 Primal Discrepancies 0.00007686 R value 4.80637820
# Iter 77 Primal Discrepancies 0.00004609 R value 4.80636546
# Iter 78 Primal Discrepancies 0.00003418 R value 4.80635313
# Iter 79 Primal Discrepancies 0.00004658 R value 4.80634421
# Iter 80 Primal Discrepancies 0.00005063 R value 4.80634006
# Iter 81 Primal Discrepancies 0.00004557 R value 4.80634053
# Iter 82 Primal Discrepancies 0.00003243 R value 4.80634435
# Iter 83 Primal Discrepancies 0.00001944 R value 4.80634973
# Iter 84 Primal Discrepancies 0.00001442 R value 4.80635493
# Iter 85 Primal Discrepancies 0.00001965 R value 4.80635869
# Iter 86 Primal Discrepancies 0.00002136 R value 4.80636044
# Iter 87 Primal Discrepancies 0.00001922 R value 4.80636024
# Iter 88 Primal Discrepancies 0.00001368 R value 4.80635863
# Iter 89 Primal Discrepancies 0.00000820 R value 4.80635636
# Iter 90 Primal Discrepancies 0.00000608 R value 4.80635417
# Iter 91 Primal Discrepancies 0.00000829 R value 4.80635258
# Iter 92 Primal Discrepancies 0.00000901 R value 4.80635184
# Iter 93 Primal Discrepancies 0.00000811 R value 4.80635193
# Iter 94 Primal Discrepancies 0.00000577 R value 4.80635261
# Iter 95 Primal Discrepancies 0.00000346 R value 4.80635356
# Iter 96 Primal Discrepancies 0.00000257 R value 4.80635449
# Iter 97 Primal Discrepancies 0.00000350 R value 4.80635516
# Iter 98 Primal Discrepancies 0.00000380 R value 4.80635547
# Iter 99 Primal Discrepancies 0.00000342 R value 4.80635544
# Iter 100 Primal Discrepancies 0.00000243 R value 4.80635515
# Iter 101 Primal Discrepancies 0.00000146 R value 4.80635475
# Iter 102 Primal Discrepancies 0.00000108 R value 4.80635436
# Iter 103 Primal Discrepancies 0.00000148 R value 4.80635407
# Iter 104 Primal Discrepancies 0.00000160 R value 4.80635394
# Iter 105 Primal Discrepancies 0.00000144 R value 4.80635396
# Iter 106 Primal Discrepancies 0.00000103 R value 4.80635408
# Iter 107 Primal Discrepancies 0.00000062 R value 4.80635425
# Iter 108 Primal Discrepancies 0.00000046 R value 4.80635441
# Iter 109 Primal Discrepancies 0.00000062 R value 4.80635453
# Iter 110 Primal Discrepancies 0.00000068 R value 4.80635459
# Iter 111 Primal Discrepancies 0.00000061 R value 4.80635458
# Iter 112 Primal Discrepancies 0.00000043 R value 4.80635453
# Iter 113 Primal Discrepancies 0.00000026 R value 4.80635446
# Iter 114 Primal Discrepancies 0.00000019 R value 4.80635439
# Iter 115 Primal Discrepancies 0.00000026 R value 4.80635434
# Iter 116 Primal Discrepancies 0.00000029 R value 4.80635431
# Iter 117 Primal Discrepancies 0.00000026 R value 4.80635432
# Iter 118 Primal Discrepancies 0.00000018 R value 4.80635434
# Iter 119 Primal Discrepancies 0.00000011 R value 4.80635437
# Iter 120 Primal Discrepancies 0.00000008 R value 4.80635440
# Iter 121 Primal Discrepancies 0.00000011 R value 4.80635442
# Iter 122 Primal Discrepancies 0.00000012 R value 4.80635443
# Iter 123 Primal Discrepancies 0.00000011 R value 4.80635443
# Iter 124 Primal Discrepancies 0.00000008 R value 4.80635442
# Stopping at iteration 124
# X = 2.420381228773749e-9
# Y = -0.9749999987655781
# R = 4.806354418824682
# Correct values are:
# X = -1.0456187885555454e-7
# Y = -0.9749997949767099
# R = 4.806354399951325

# %%
##QP_ADMM for 4 selected circles in n=10, m=25 test case

using JuMP
using Printf
import Juniper
import Ipopt

a = [46.89, 18.36, 24.81, 14.31, 45.81]
b = [34.21, 34.21, 15.03, 5.03, 17.23]
r = [20, 20, 20, 20, 20 ]
NumVar = size(r)[1] 

rho = 1.0  ### Augmented Lagrangian penalty coefficient
  ## Note: rho may be allowed to vary under restriction


## Typing of parameters is optional, but wise.
## Form the AL primal subproblem
function solveSP(i::Int64, vdual::Dict{String,Float64}, X::Float64,Y::Float64, R::Float64 )

  model = Model(
        optimizer_with_attributes(
            #Juniper.Optimizer,
            #"nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
            #    MOI.Silent() => true,
            #),
        ),
    )
    set_optimizer_attribute(model, "print_level", 0)  ### Suppress Ipopt output
    set_optimizer_attribute(model, "tol", 1e-14)  ### Not required in general

    @variable(model, x )
    @variable(model, y )
    @variable(model, z >= 0)
  
    ### primal objective + Lagrange terms + augmented (squared penalty) terms
    @objective(model, Min, z+r[i] 
	+ vdual["x"]*(x + X - a[i]) + vdual["y"]*(y + Y - b[i]) + vdual["z"]*(z + r[i] - R)
	+ 0.5*rho*( (x+X-a[i])^2 + (y+Y-b[i])^2 + (z+r[i]-R)^2 ) )

    ### All coupling constraints are relaxed.
    @constraint( model, xyz, x^2 + y^2 <= z^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
  ## Initialization
    x = Dict{Int64,Float64}()
    y = Dict{Int64,Float64}()
    z = Dict{Int64,Float64}()

    ### Initialize Lagrangian multipliers to zero value
    vdual = Dict{Int64, Dict{String,Float64}}()
    for i in 1:NumVar
	vdual[i] = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    end

    X,Y,R=0.0,0.0,0.0
    oldX,oldY,oldR=0.0,0.0,0.0
    ### Initialize R to average of r[i], i=1,...,n
    for i in 1:length(a)
	R += (1.0/NumVar)*(r[i])
    end
  ## End of initialization

for n in 1:1000
    ### Solve AL subproblem for each subproblem i with X,Y,R fixed
    for i in 1:NumVar
      x[i],y[i],z[i] = solveSP(i,vdual[i],X,Y,R)
    end

    ### Subproblems in X,Y,R (with x,y,z fixed) can be solved in closed-form
    oldX,oldY,oldR=X,Y,R
    X,Y,R=0.0,0.0,0.0
    for i in 1:NumVar
	X += (1.0/NumVar)*(a[i]-x[i])
	Y += (1.0/NumVar)*(b[i]-y[i])
	R += (1.0/NumVar)*(z[i]+r[i])
    end

    ### Update Lagrange multipliers, compute a measure of primal infeasibility.
    discr = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    for i in 1:NumVar
	vdual[i]["x"] += rho*(x[i] + X - a[i]) 
	vdual[i]["y"] += rho*(y[i] + Y - b[i]) 
	vdual[i]["z"] += rho*(z[i] + r[i] - R)

	discr["x"] += abs(x[i] + X - a[i])
	discr["y"] += abs(y[i] + Y - b[i])
	discr["z"] += abs(z[i] + r[i] - R)
    end
    @printf("Iter %d Primal Discrepancies %8.8f R value %8.8f\n", 
	n, discr["x"] + discr["y"] + discr["z"], R)
    d_discr = abs(X-oldX)+abs(Y-oldY)+abs(R-oldR) ### Dual residues
    if discr["x"] + discr["y"] + discr["z"] + d_discr < 1e-7
	println("Stopping at iteration ",n)  ### Primal feasible within tolerance
	break
    end
end
    @show(X)
    @show(Y)
    @show(R)

println("Correct values are: ")

println("X = ",30.599999991460297)
println("Y = ",19.62000000953417)
println("R = ",41.868520759503134)
end

main()
# Out:
# Iter 1 Primal Discrepancies 91.12239784 R value 38.49874235
# Iter 2 Primal Discrepancies 33.42531768 R value 45.71044490
# Iter 3 Primal Discrepancies 36.76520860 R value 49.35202882
# Iter 4 Primal Discrepancies 29.63002468 R value 50.80314363
# Iter 5 Primal Discrepancies 18.39572260 R value 51.29969065
# Iter 6 Primal Discrepancies 18.53104863 R value 50.83332874
# Iter 7 Primal Discrepancies 10.26656969 R value 49.83332874
# Iter 8 Primal Discrepancies 0.00000000 R value 48.83332874
# Iter 9 Primal Discrepancies 0.00000000 R value 47.83332874
# Iter 10 Primal Discrepancies 0.00000000 R value 46.83332874
# Iter 11 Primal Discrepancies 0.00000000 R value 45.83332874
# Iter 12 Primal Discrepancies 0.00000000 R value 44.83332874
# Iter 13 Primal Discrepancies 0.00000000 R value 43.83332874
# Iter 14 Primal Discrepancies 0.57090713 R value 42.86300505
# Iter 15 Primal Discrepancies 2.26632455 R value 42.01048716
# Iter 16 Primal Discrepancies 3.16939357 R value 41.32271748
# Iter 17 Primal Discrepancies 3.67676846 R value 40.89010400
# Iter 18 Primal Discrepancies 3.85245786 R value 40.74752020
# Iter 19 Primal Discrepancies 3.75927953 R value 40.86468730
# Iter 20 Primal Discrepancies 3.03416016 R value 41.16538294
# Iter 21 Primal Discrepancies 2.13678436 R value 41.55197851
# Iter 22 Primal Discrepancies 1.58479403 R value 41.92930492
# Iter 23 Primal Discrepancies 1.53734208 R value 42.22321014
# Iter 24 Primal Discrepancies 1.76422559 R value 42.39117442
# Iter 25 Primal Discrepancies 1.81961457 R value 42.42446396
# Iter 26 Primal Discrepancies 1.69384043 R value 42.34309405
# Iter 27 Primal Discrepancies 1.33930914 R value 42.18605172
# Iter 28 Primal Discrepancies 0.93837786 R value 41.99968357
# Iter 29 Primal Discrepancies 0.72735338 R value 41.82693996
# Iter 30 Primal Discrepancies 0.74183051 R value 41.69945600
# Iter 31 Primal Discrepancies 0.84105023 R value 41.63348585
# Iter 32 Primal Discrepancies 0.85748860 R value 41.62973091
# Iter 33 Primal Discrepancies 0.75961715 R value 41.67631541
# Iter 34 Primal Discrepancies 0.58732372 R value 41.75368224
# Iter 35 Primal Discrepancies 0.41461757 R value 41.84004445
# Iter 36 Primal Discrepancies 0.32755803 R value 41.91619028
# Iter 37 Primal Discrepancies 0.35854189 R value 41.96881021
# Iter 38 Primal Discrepancies 0.39253556 R value 41.99197688
# Iter 39 Primal Discrepancies 0.39782686 R value 41.98685180
# Iter 40 Primal Discrepancies 0.33534265 R value 41.96003289
# Iter 41 Primal Discrepancies 0.25324245 R value 41.92114536
# Iter 42 Primal Discrepancies 0.18166325 R value 41.88030950
# Iter 43 Primal Discrepancies 0.15315869 R value 41.84601635
# Iter 44 Primal Discrepancies 0.17714231 R value 41.82375467
# Iter 45 Primal Discrepancies 0.18535976 R value 41.81551330
# Iter 46 Primal Discrepancies 0.18356027 R value 41.82008333
# Iter 47 Primal Discrepancies 0.14971085 R value 41.83393942
# Iter 48 Primal Discrepancies 0.10810502 R value 41.85240817
# Iter 49 Primal Discrepancies 0.07819199 R value 41.87083228
# Iter 50 Primal Discrepancies 0.07413686 R value 41.88549865
# Iter 51 Primal Discrepancies 0.08491361 R value 41.89419183
# Iter 52 Primal Discrepancies 0.08810357 R value 41.89633726
# Iter 53 Primal Discrepancies 0.08340947 R value 41.89278765
# Iter 54 Primal Discrepancies 0.06667923 R value 41.88536667
# Iter 55 Primal Discrepancies 0.04694557 R value 41.87630970
# Iter 56 Primal Discrepancies 0.03625403 R value 41.86773419
# Iter 57 Primal Discrepancies 0.03609469 R value 41.86123955
# Iter 58 Primal Discrepancies 0.04092439 R value 41.85769072
# Iter 59 Primal Discrepancies 0.04158024 R value 41.85719194
# Iter 60 Primal Discrepancies 0.03763866 R value 41.85921798
# Iter 61 Primal Discrepancies 0.02940991 R value 41.86284492
# Iter 62 Primal Discrepancies 0.02063061 R value 41.86701465
# Iter 63 Primal Discrepancies 0.01614876 R value 41.87077320
# Iter 64 Primal Discrepancies 0.01691584 R value 41.87344064
# Iter 65 Primal Discrepancies 0.01988897 R value 41.87469216
# Iter 66 Primal Discrepancies 0.01943963 R value 41.87455193
# Iter 67 Primal Discrepancies 0.01676613 R value 41.87331840
# Iter 68 Primal Discrepancies 0.01282262 R value 41.87144966
# Iter 69 Primal Discrepancies 0.00924684 R value 41.86943986
# Iter 70 Primal Discrepancies 0.00793649 R value 41.86771310
# Iter 71 Primal Discrepancies 0.00852979 R value 41.86655256
# Iter 72 Primal Discrepancies 0.00984137 R value 41.86607202
# Iter 73 Primal Discrepancies 0.00926399 R value 41.86622692
# Iter 74 Primal Discrepancies 0.00738625 R value 41.86685495
# Iter 75 Primal Discrepancies 0.00567501 R value 41.86773197
# Iter 76 Primal Discrepancies 0.00387725 R value 41.86862923
# Iter 77 Primal Discrepancies 0.00371933 R value 41.86935997
# Iter 78 Primal Discrepancies 0.00445307 R value 41.86980837
# Iter 79 Primal Discrepancies 0.00486528 R value 41.86993851
# Iter 80 Primal Discrepancies 0.00435515 R value 41.86978553
# Iter 81 Primal Discrepancies 0.00334481 R value 41.86943438
# Iter 82 Primal Discrepancies 0.00267263 R value 41.86899285
# Iter 83 Primal Discrepancies 0.00188952 R value 41.86856542
# Iter 84 Primal Discrepancies 0.00207801 R value 41.86823303
# Iter 85 Primal Discrepancies 0.00237664 R value 41.86804156
# Iter 86 Primal Discrepancies 0.00247717 R value 41.86799967
# Iter 87 Primal Discrepancies 0.00216435 R value 41.86808450
# Iter 88 Primal Discrepancies 0.00174566 R value 41.86825253
# Iter 89 Primal Discrepancies 0.00139421 R value 41.86845240
# Iter 90 Primal Discrepancies 0.00122354 R value 41.86863675
# Iter 91 Primal Discrepancies 0.00118477 R value 41.86877090
# Iter 92 Primal Discrepancies 0.00128433 R value 41.86883721
# Iter 93 Primal Discrepancies 0.00126804 R value 41.86883521
# Iter 94 Primal Discrepancies 0.00113572 R value 41.86877826
# Iter 95 Primal Discrepancies 0.00097850 R value 41.86868808
# Iter 96 Primal Discrepancies 0.00083535 R value 41.86858878
# Iter 97 Primal Discrepancies 0.00078048 R value 41.86850149
# Iter 98 Primal Discrepancies 0.00075901 R value 41.86844077
# Iter 99 Primal Discrepancies 0.00077598 R value 41.86841301
# Iter 100 Primal Discrepancies 0.00074638 R value 41.86841675
# Iter 101 Primal Discrepancies 0.00068052 R value 41.86844457
# Iter 102 Primal Discrepancies 0.00063315 R value 41.86848573
# Iter 103 Primal Discrepancies 0.00056968 R value 41.86852903
# Iter 104 Primal Discrepancies 0.00054193 R value 41.86856509
# Iter 105 Primal Discrepancies 0.00052508 R value 41.86858788
# Iter 106 Primal Discrepancies 0.00051607 R value 41.86859525
# Iter 107 Primal Discrepancies 0.00048720 R value 41.86858860
# Iter 108 Primal Discrepancies 0.00044831 R value 41.86857186
# Iter 109 Primal Discrepancies 0.00041855 R value 41.86855021
# Iter 110 Primal Discrepancies 0.00038378 R value 41.86852879
# Iter 111 Primal Discrepancies 0.00037108 R value 41.86851169
# Iter 112 Primal Discrepancies 0.00036307 R value 41.86850132
# Iter 113 Primal Discrepancies 0.00035359 R value 41.86849828
# Iter 114 Primal Discrepancies 0.00033501 R value 41.86850160
# Iter 115 Primal Discrepancies 0.00031395 R value 41.86850923
# Iter 116 Primal Discrepancies 0.00029469 R value 41.86851869
# Iter 117 Primal Discrepancies 0.00027564 R value 41.86852763
# Iter 118 Primal Discrepancies 0.00026388 R value 41.86853428
# Iter 119 Primal Discrepancies 0.00025609 R value 41.86853769
# Iter 120 Primal Discrepancies 0.00024585 R value 41.86853777
# Iter 121 Primal Discrepancies 0.00023204 R value 41.86853510
# Iter 122 Primal Discrepancies 0.00021909 R value 41.86853070
# Iter 123 Primal Discrepancies 0.00020636 R value 41.86852576
# Iter 124 Primal Discrepancies 0.00019599 R value 41.86852131
# Iter 125 Primal Discrepancies 0.00018775 R value 41.86851811
# Iter 126 Primal Discrepancies 0.00018220 R value 41.86851650
# Iter 127 Primal Discrepancies 0.00017463 R value 41.86851646
# Iter 128 Primal Discrepancies 0.00016552 R value 41.86851764
# Iter 129 Primal Discrepancies 0.00015728 R value 41.86851954
# Iter 130 Primal Discrepancies 0.00014873 R value 41.86852159
# Iter 131 Primal Discrepancies 0.00014182 R value 41.86852334
# Iter 132 Primal Discrepancies 0.00013579 R value 41.86852448
# Iter 133 Primal Discrepancies 0.00013063 R value 41.86852487
# Iter 134 Primal Discrepancies 0.00012469 R value 41.86852456
# Iter 135 Primal Discrepancies 0.00011833 R value 41.86852375
# Iter 136 Primal Discrepancies 0.00011270 R value 41.86852267
# Iter 137 Primal Discrepancies 0.00010692 R value 41.86852159
# Iter 138 Primal Discrepancies 0.00010242 R value 41.86852070
# Iter 139 Primal Discrepancies 0.00009828 R value 41.86852013
# Iter 140 Primal Discrepancies 0.00009433 R value 41.86851992
# Iter 141 Primal Discrepancies 0.00009009 R value 41.86852004
# Iter 142 Primal Discrepancies 0.00008580 R value 41.86852037
# Iter 143 Primal Discrepancies 0.00008179 R value 41.86852081
# Iter 144 Primal Discrepancies 0.00007785 R value 41.86852123
# Iter 145 Primal Discrepancies 0.00007447 R value 41.86852155
# Iter 146 Primal Discrepancies 0.00007136 R value 41.86852172
# Iter 147 Primal Discrepancies 0.00006830 R value 41.86852173
# Iter 148 Primal Discrepancies 0.00006517 R value 41.86852160
# Iter 149 Primal Discrepancies 0.00006217 R value 41.86852138
# Iter 150 Primal Discrepancies 0.00005930 R value 41.86852113
# Iter 151 Primal Discrepancies 0.00005662 R value 41.86852090
# Iter 152 Primal Discrepancies 0.00005415 R value 41.86852073
# Iter 153 Primal Discrepancies 0.00005191 R value 41.86852063
# Iter 154 Primal Discrepancies 0.00004966 R value 41.86852062
# Iter 155 Primal Discrepancies 0.00004742 R value 41.86852066
# Iter 156 Primal Discrepancies 0.00004529 R value 41.86852075
# Iter 157 Primal Discrepancies 0.00004322 R value 41.86852084
# Iter 158 Primal Discrepancies 0.00004130 R value 41.86852093
# Iter 159 Primal Discrepancies 0.00003949 R value 41.86852098
# Iter 160 Primal Discrepancies 0.00003780 R value 41.86852100
# Iter 161 Primal Discrepancies 0.00003614 R value 41.86852098
# Iter 162 Primal Discrepancies 0.00003451 R value 41.86852094
# Iter 163 Primal Discrepancies 0.00003297 R value 41.86852089
# Iter 164 Primal Discrepancies 0.00003149 R value 41.86852083
# Iter 165 Primal Discrepancies 0.00003011 R value 41.86852078
# Iter 166 Primal Discrepancies 0.00002881 R value 41.86852075
# Iter 167 Primal Discrepancies 0.00002756 R value 41.86852074
# Iter 168 Primal Discrepancies 0.00002635 R value 41.86852074
# Iter 169 Primal Discrepancies 0.00002518 R value 41.86852075
# Iter 170 Primal Discrepancies 0.00002406 R value 41.86852077
# Iter 171 Primal Discrepancies 0.00002299 R value 41.86852079
# Iter 172 Primal Discrepancies 0.00002198 R value 41.86852081
# Iter 173 Primal Discrepancies 0.00002102 R value 41.86852081
# Iter 174 Primal Discrepancies 0.00002011 R value 41.86852081
# Iter 175 Primal Discrepancies 0.00001922 R value 41.86852081
# Iter 176 Primal Discrepancies 0.00001837 R value 41.86852080
# Iter 177 Primal Discrepancies 0.00001756 R value 41.86852078
# Iter 178 Primal Discrepancies 0.00001678 R value 41.86852077
# Iter 179 Primal Discrepancies 0.00001605 R value 41.86852076
# Iter 180 Primal Discrepancies 0.00001535 R value 41.86852076
# Iter 181 Primal Discrepancies 0.00001468 R value 41.86852075
# Iter 182 Primal Discrepancies 0.00001403 R value 41.86852076
# Iter 183 Primal Discrepancies 0.00001341 R value 41.86852076
# Iter 184 Primal Discrepancies 0.00001282 R value 41.86852076
# Iter 185 Primal Discrepancies 0.00001226 R value 41.86852077
# Iter 186 Primal Discrepancies 0.00001172 R value 41.86852077
# Iter 187 Primal Discrepancies 0.00001121 R value 41.86852077
# Iter 188 Primal Discrepancies 0.00001072 R value 41.86852077
# Iter 189 Primal Discrepancies 0.00001024 R value 41.86852077
# Iter 190 Primal Discrepancies 0.00000979 R value 41.86852076
# Iter 191 Primal Discrepancies 0.00000936 R value 41.86852076
# Iter 192 Primal Discrepancies 0.00000895 R value 41.86852076
# Iter 193 Primal Discrepancies 0.00000856 R value 41.86852076
# Iter 194 Primal Discrepancies 0.00000818 R value 41.86852076
# Iter 195 Primal Discrepancies 0.00000783 R value 41.86852076
# Iter 196 Primal Discrepancies 0.00000748 R value 41.86852076
# Iter 197 Primal Discrepancies 0.00000715 R value 41.86852076
# Iter 198 Primal Discrepancies 0.00000684 R value 41.86852076
# Iter 199 Primal Discrepancies 0.00000654 R value 41.86852076
# Iter 200 Primal Discrepancies 0.00000625 R value 41.86852076
# Iter 201 Primal Discrepancies 0.00000598 R value 41.86852076
# Iter 202 Primal Discrepancies 0.00000572 R value 41.86852076
# Iter 203 Primal Discrepancies 0.00000546 R value 41.86852076
# Iter 204 Primal Discrepancies 0.00000522 R value 41.86852076
# Iter 205 Primal Discrepancies 0.00000500 R value 41.86852076
# Iter 206 Primal Discrepancies 0.00000478 R value 41.86852076
# Iter 207 Primal Discrepancies 0.00000457 R value 41.86852076
# Iter 208 Primal Discrepancies 0.00000437 R value 41.86852076
# Iter 209 Primal Discrepancies 0.00000418 R value 41.86852076
# Iter 210 Primal Discrepancies 0.00000399 R value 41.86852076
# Iter 211 Primal Discrepancies 0.00000382 R value 41.86852076
# Iter 212 Primal Discrepancies 0.00000365 R value 41.86852076
# Iter 213 Primal Discrepancies 0.00000349 R value 41.86852076
# Iter 214 Primal Discrepancies 0.00000334 R value 41.86852076
# Iter 215 Primal Discrepancies 0.00000319 R value 41.86852076
# Iter 216 Primal Discrepancies 0.00000305 R value 41.86852076
# Iter 217 Primal Discrepancies 0.00000292 R value 41.86852076
# Iter 218 Primal Discrepancies 0.00000279 R value 41.86852076
# Iter 219 Primal Discrepancies 0.00000267 R value 41.86852075
# Iter 220 Primal Discrepancies 0.00000255 R value 41.86852075
# Iter 221 Primal Discrepancies 0.00000244 R value 41.86852075
# Iter 222 Primal Discrepancies 0.00000233 R value 41.86852075
# Iter 223 Primal Discrepancies 0.00000223 R value 41.86852075
# Iter 224 Primal Discrepancies 0.00000213 R value 41.86852075
# Iter 225 Primal Discrepancies 0.00000204 R value 41.86852075
# Iter 226 Primal Discrepancies 0.00000195 R value 41.86852075
# Iter 227 Primal Discrepancies 0.00000186 R value 41.86852075
# Iter 228 Primal Discrepancies 0.00000178 R value 41.86852075
# Iter 229 Primal Discrepancies 0.00000170 R value 41.86852075
# Iter 230 Primal Discrepancies 0.00000163 R value 41.86852075
# Iter 231 Primal Discrepancies 0.00000156 R value 41.86852075
# Iter 232 Primal Discrepancies 0.00000149 R value 41.86852075
# Iter 233 Primal Discrepancies 0.00000142 R value 41.86852075
# Iter 234 Primal Discrepancies 0.00000136 R value 41.86852075
# Iter 235 Primal Discrepancies 0.00000130 R value 41.86852075
# Iter 236 Primal Discrepancies 0.00000124 R value 41.86852075
# Iter 237 Primal Discrepancies 0.00000119 R value 41.86852075
# Iter 238 Primal Discrepancies 0.00000114 R value 41.86852075
# Iter 239 Primal Discrepancies 0.00000109 R value 41.86852075
# Iter 240 Primal Discrepancies 0.00000104 R value 41.86852075
# Iter 241 Primal Discrepancies 0.00000099 R value 41.86852075
# Iter 242 Primal Discrepancies 0.00000095 R value 41.86852075
# Iter 243 Primal Discrepancies 0.00000091 R value 41.86852075
# Iter 244 Primal Discrepancies 0.00000087 R value 41.86852075
# Iter 245 Primal Discrepancies 0.00000083 R value 41.86852075
# Iter 246 Primal Discrepancies 0.00000079 R value 41.86852075
# Iter 247 Primal Discrepancies 0.00000076 R value 41.86852075
# Iter 248 Primal Discrepancies 0.00000073 R value 41.86852075
# Iter 249 Primal Discrepancies 0.00000069 R value 41.86852075
# Iter 250 Primal Discrepancies 0.00000066 R value 41.86852075
# Iter 251 Primal Discrepancies 0.00000063 R value 41.86852075
# Iter 252 Primal Discrepancies 0.00000061 R value 41.86852075
# Iter 253 Primal Discrepancies 0.00000058 R value 41.86852075
# Iter 254 Primal Discrepancies 0.00000055 R value 41.86852075
# Iter 255 Primal Discrepancies 0.00000053 R value 41.86852075
# Iter 256 Primal Discrepancies 0.00000051 R value 41.86852075
# Iter 257 Primal Discrepancies 0.00000048 R value 41.86852075
# Iter 258 Primal Discrepancies 0.00000046 R value 41.86852075
# Iter 259 Primal Discrepancies 0.00000044 R value 41.86852075
# Iter 260 Primal Discrepancies 0.00000042 R value 41.86852075
# Iter 261 Primal Discrepancies 0.00000041 R value 41.86852075
# Iter 262 Primal Discrepancies 0.00000039 R value 41.86852075
# Iter 263 Primal Discrepancies 0.00000037 R value 41.86852075
# Iter 264 Primal Discrepancies 0.00000035 R value 41.86852075
# Iter 265 Primal Discrepancies 0.00000034 R value 41.86852075
# Iter 266 Primal Discrepancies 0.00000032 R value 41.86852075
# Iter 267 Primal Discrepancies 0.00000031 R value 41.86852075
# Iter 268 Primal Discrepancies 0.00000030 R value 41.86852075
# Iter 269 Primal Discrepancies 0.00000028 R value 41.86852075
# Iter 270 Primal Discrepancies 0.00000027 R value 41.86852075
# Iter 271 Primal Discrepancies 0.00000026 R value 41.86852075
# Iter 272 Primal Discrepancies 0.00000025 R value 41.86852075
# Iter 273 Primal Discrepancies 0.00000024 R value 41.86852075
# Iter 274 Primal Discrepancies 0.00000023 R value 41.86852075
# Iter 275 Primal Discrepancies 0.00000022 R value 41.86852075
# Iter 276 Primal Discrepancies 0.00000021 R value 41.86852075
# Iter 277 Primal Discrepancies 0.00000020 R value 41.86852075
# Iter 278 Primal Discrepancies 0.00000019 R value 41.86852075
# Iter 279 Primal Discrepancies 0.00000018 R value 41.86852075
# Iter 280 Primal Discrepancies 0.00000017 R value 41.86852075
# Iter 281 Primal Discrepancies 0.00000017 R value 41.86852075
# Iter 282 Primal Discrepancies 0.00000016 R value 41.86852075
# Iter 283 Primal Discrepancies 0.00000015 R value 41.86852075
# Iter 284 Primal Discrepancies 0.00000014 R value 41.86852075
# Iter 285 Primal Discrepancies 0.00000014 R value 41.86852075
# Iter 286 Primal Discrepancies 0.00000013 R value 41.86852075
# Iter 287 Primal Discrepancies 0.00000013 R value 41.86852075
# Iter 288 Primal Discrepancies 0.00000012 R value 41.86852075
# Iter 289 Primal Discrepancies 0.00000012 R value 41.86852075
# Iter 290 Primal Discrepancies 0.00000011 R value 41.86852075
# Iter 291 Primal Discrepancies 0.00000011 R value 41.86852075
# Iter 292 Primal Discrepancies 0.00000010 R value 41.86852075
# Iter 293 Primal Discrepancies 0.00000010 R value 41.86852075
# Iter 294 Primal Discrepancies 0.00000009 R value 41.86852075
# Iter 295 Primal Discrepancies 0.00000009 R value 41.86852075
# Iter 296 Primal Discrepancies 0.00000008 R value 41.86852075
# Iter 297 Primal Discrepancies 0.00000008 R value 41.86852075
# Iter 298 Primal Discrepancies 0.00000008 R value 41.86852075
# Iter 299 Primal Discrepancies 0.00000007 R value 41.86852075
# Iter 300 Primal Discrepancies 0.00000007 R value 41.86852075
# Iter 301 Primal Discrepancies 0.00000007 R value 41.86852075
# Iter 302 Primal Discrepancies 0.00000006 R value 41.86852075
# Iter 303 Primal Discrepancies 0.00000006 R value 41.86852075
# Iter 304 Primal Discrepancies 0.00000006 R value 41.86852075
# Iter 305 Primal Discrepancies 0.00000006 R value 41.86852075
# Iter 306 Primal Discrepancies 0.00000005 R value 41.86852075
# Iter 307 Primal Discrepancies 0.00000005 R value 41.86852075
# Iter 308 Primal Discrepancies 0.00000005 R value 41.86852075
# Iter 309 Primal Discrepancies 0.00000005 R value 41.86852075
# Iter 310 Primal Discrepancies 0.00000005 R value 41.86852075
# Iter 311 Primal Discrepancies 0.00000004 R value 41.86852075
# Iter 312 Primal Discrepancies 0.00000004 R value 41.86852075
# Iter 313 Primal Discrepancies 0.00000004 R value 41.86852075
# Iter 314 Primal Discrepancies 0.00000004 R value 41.86852075
# Iter 315 Primal Discrepancies 0.00000004 R value 41.86852075
# Iter 316 Primal Discrepancies 0.00000003 R value 41.86852075
# Iter 317 Primal Discrepancies 0.00000003 R value 41.86852075
# Iter 318 Primal Discrepancies 0.00000003 R value 41.86852075
# Iter 319 Primal Discrepancies 0.00000003 R value 41.86852075
# Iter 320 Primal Discrepancies 0.00000003 R value 41.86852075
# Iter 321 Primal Discrepancies 0.00000003 R value 41.86852075
# Iter 322 Primal Discrepancies 0.00000003 R value 41.86852075
# Iter 323 Primal Discrepancies 0.00000003 R value 41.86852075
# Iter 324 Primal Discrepancies 0.00000002 R value 41.86852075
# Iter 325 Primal Discrepancies 0.00000002 R value 41.86852075
# Iter 326 Primal Discrepancies 0.00000002 R value 41.86852075
# Iter 327 Primal Discrepancies 0.00000002 R value 41.86852075
# Stopping at iteration 327
# X = 30.599999214382674
# Y = 19.620000877156038
# R = 41.86852075450012
# Correct values are:
# X = 30.599999991460297
# Y = 19.62000000953417
# R = 41.868520759503134

# %%
##QP_ADMM for 4 selected circles in n=10, m=50 test case

using JuMP
using Printf
import Juniper
import Ipopt

a = [13.239512466541303, 5.513695828127543, 41.55335924184264, 43.70990076229758] # x-cordinates of selected circle
b = [43.945805488954605, 14.997506943080591, 31.204816928920724, 15.106911655793608] # y-cordinates of selected circle
r = [20, 20, 20, 20 ] # Radius of selected cirlcles

NumVar = size(r)[1] 

rho = 1.0  ### Augmented Lagrangian penalty coefficient
  ## Note: rho may be allowed to vary under restriction


## Typing of parameters is optional, but wise.
## Form the AL primal subproblem
function solveSP(i::Int64, vdual::Dict{String,Float64}, X::Float64,Y::Float64, R::Float64 )

  model = Model(
        optimizer_with_attributes(
            #Juniper.Optimizer,
            #"nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
            #    MOI.Silent() => true,
            #),
        ),
    )
    set_optimizer_attribute(model, "print_level", 0)  ### Suppress Ipopt output
    set_optimizer_attribute(model, "tol", 1e-14)  ### Not required in general

    @variable(model, x )
    @variable(model, y )
    @variable(model, z >= 0)
  
    ### primal objective + Lagrange terms + augmented (squared penalty) terms
    @objective(model, Min, z+r[i] 
	+ vdual["x"]*(x + X - a[i]) + vdual["y"]*(y + Y - b[i]) + vdual["z"]*(z + r[i] - R)
	+ 0.5*rho*( (x+X-a[i])^2 + (y+Y-b[i])^2 + (z+r[i]-R)^2 ) )

    ### All coupling constraints are relaxed.
    @constraint( model, xyz, x^2 + y^2 <= z^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
  ## Initialization
    x = Dict{Int64,Float64}()
    y = Dict{Int64,Float64}()
    z = Dict{Int64,Float64}()

    ### Initialize Lagrangian multipliers to zero value
    vdual = Dict{Int64, Dict{String,Float64}}()
    for i in 1:NumVar
	vdual[i] = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    end

    X,Y,R=0.0,0.0,0.0
    oldX,oldY,oldR=0.0,0.0,0.0
    ### Initialize R to average of r[i], i=1,...,n
    for i in 1:length(a)
	R += (1.0/NumVar)*(r[i])
    end
  ## End of initialization

for n in 1:1000
    ### Solve AL subproblem for each subproblem i with X,Y,R fixed
    for i in 1:NumVar
      x[i],y[i],z[i] = solveSP(i,vdual[i],X,Y,R)
    end

    ### Subproblems in X,Y,R (with x,y,z fixed) can be solved in closed-form
    oldX,oldY,oldR=X,Y,R
    X,Y,R=0.0,0.0,0.0
    for i in 1:NumVar
	X += (1.0/NumVar)*(a[i]-x[i])
	Y += (1.0/NumVar)*(b[i]-y[i])
	R += (1.0/NumVar)*(z[i]+r[i])
    end

    ### Update Lagrange multipliers, compute a measure of primal infeasibility.
    discr = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    for i in 1:NumVar
	vdual[i]["x"] += rho*(x[i] + X - a[i]) 
	vdual[i]["y"] += rho*(y[i] + Y - b[i]) 
	vdual[i]["z"] += rho*(z[i] + r[i] - R)

	discr["x"] += abs(x[i] + X - a[i])
	discr["y"] += abs(y[i] + Y - b[i])
	discr["z"] += abs(z[i] + r[i] - R)
    end
    @printf("Iter %d Primal Discrepancies %8.8f R value %8.8f\n", 
	n, discr["x"] + discr["y"] + discr["z"], R)
    d_discr = abs(X-oldX)+abs(Y-oldY)+abs(R-oldR) ### Dual residues
    if discr["x"] + discr["y"] + discr["z"] + d_discr < 1e-7
	println("Stopping at iteration ",n)  ### Primal feasible within tolerance
	break
    end
end
    @show(X)
    @show(Y)
    @show(R)

println("Correct values are: ")

println("X = ",24.58212046374567)
println("Y = ",25.41355826361457)
println("R = ",41.7278379893865)
end

main()
# Out:
# Iter 1 Primal Discrepancies 80.52325487 R value 39.51102756
# Iter 2 Primal Discrepancies 16.83723797 R value 48.18803002
# Iter 3 Primal Discrepancies 39.21615848 R value 50.94697438
# Iter 4 Primal Discrepancies 25.29154790 R value 50.19679792
# Iter 5 Primal Discrepancies 3.44454324 R value 49.19679792
# Iter 6 Primal Discrepancies 0.00000000 R value 48.19679792
# Iter 7 Primal Discrepancies 0.00000000 R value 47.19679792
# Iter 8 Primal Discrepancies 0.00000000 R value 46.19679792
# Iter 9 Primal Discrepancies 0.00000000 R value 45.19679792
# Iter 10 Primal Discrepancies 1.52529031 R value 44.31000895
# Iter 11 Primal Discrepancies 2.50015802 R value 43.71474007
# Iter 12 Primal Discrepancies 2.51773515 R value 43.43900606
# Iter 13 Primal Discrepancies 1.84582768 R value 43.33683101
# Iter 14 Primal Discrepancies 1.48890836 R value 43.26405883
# Iter 15 Primal Discrepancies 1.22735621 R value 43.19922197
# Iter 16 Primal Discrepancies 1.18293211 R value 43.16399602
# Iter 17 Primal Discrepancies 0.98436373 R value 43.11543519
# Iter 18 Primal Discrepancies 0.79856779 R value 43.03030911
# Iter 19 Primal Discrepancies 0.49997318 R value 42.90516189
# Iter 20 Primal Discrepancies 0.30383361 R value 42.75099756
# Iter 21 Primal Discrepancies 0.33391573 R value 42.58566666
# Iter 22 Primal Discrepancies 0.50798761 R value 42.42675405
# Iter 23 Primal Discrepancies 0.57986593 R value 42.28673890
# Iter 24 Primal Discrepancies 0.51300099 R value 42.17103288
# Iter 25 Primal Discrepancies 0.36303856 R value 42.07853926
# Iter 26 Primal Discrepancies 0.20284468 R value 42.00380684
# Iter 27 Primal Discrepancies 0.16778688 R value 41.93971129
# Iter 28 Primal Discrepancies 0.22881812 R value 41.87978624
# Iter 29 Primal Discrepancies 0.23950353 R value 41.81969026
# Iter 30 Primal Discrepancies 0.21094011 R value 41.75768162
# Iter 31 Primal Discrepancies 0.29162014 R value 41.71347610
# Iter 32 Primal Discrepancies 0.64381957 R value 41.70883172
# Iter 33 Primal Discrepancies 0.83567431 R value 41.73744629
# Iter 34 Primal Discrepancies 0.89923172 R value 41.77816447
# Iter 35 Primal Discrepancies 0.90373473 R value 41.80954715
# Iter 36 Primal Discrepancies 0.82004908 R value 41.81924586
# Iter 37 Primal Discrepancies 0.64535219 R value 41.80629172
# Iter 38 Primal Discrepancies 0.41445877 R value 41.77803540
# Iter 39 Primal Discrepancies 0.16689029 R value 41.74493986
# Iter 40 Primal Discrepancies 0.06720611 R value 41.71602774
# Iter 41 Primal Discrepancies 0.24539860 R value 41.69644708
# Iter 42 Primal Discrepancies 0.36885292 R value 41.68724998
# Iter 43 Primal Discrepancies 0.42880713 R value 41.68661812
# Iter 44 Primal Discrepancies 0.43056396 R value 41.69153799
# Iter 45 Primal Discrepancies 0.38515788 R value 41.69916014
# Iter 46 Primal Discrepancies 0.30674648 R value 41.70749944
# Iter 47 Primal Discrepancies 0.21534375 R value 41.71551381
# Iter 48 Primal Discrepancies 0.11578638 R value 41.72281176
# Iter 49 Primal Discrepancies 0.02814348 R value 41.72927250
# Iter 50 Primal Discrepancies 0.07700450 R value 41.73477374
# Iter 51 Primal Discrepancies 0.14059167 R value 41.73909645
# Iter 52 Primal Discrepancies 0.18050123 R value 41.74197370
# Iter 53 Primal Discrepancies 0.19604069 R value 41.74320358
# Iter 54 Primal Discrepancies 0.18893733 R value 41.74274955
# Iter 55 Primal Discrepancies 0.16293147 R value 41.74078333
# Iter 56 Primal Discrepancies 0.12321867 R value 41.73766324
# Iter 57 Primal Discrepancies 0.07578621 R value 41.73386665
# Iter 58 Primal Discrepancies 0.02671212 R value 41.72990518
# Iter 59 Primal Discrepancies 0.01881796 R value 41.72624703
# Iter 60 Primal Discrepancies 0.05543204 R value 41.72326122
# Iter 61 Primal Discrepancies 0.08117615 R value 41.72118752
# Iter 62 Primal Discrepancies 0.09442774 R value 41.72012933
# Iter 63 Primal Discrepancies 0.09545854 R value 41.72006358
# Iter 64 Primal Discrepancies 0.08587193 R value 41.72086206
# Iter 65 Primal Discrepancies 0.06823623 R value 41.72231967
# Iter 66 Primal Discrepancies 0.04565420 R value 41.72418619
# Iter 67 Primal Discrepancies 0.02133239 R value 41.72619894
# Iter 68 Primal Discrepancies 0.00324300 R value 41.72811313
# Iter 69 Primal Discrepancies 0.02136269 R value 41.72972740
# Iter 70 Primal Discrepancies 0.03573771 R value 41.73090157
# Iter 71 Primal Discrepancies 0.04410521 R value 41.73156525
# Iter 72 Primal Discrepancies 0.04642907 R value 41.73171690
# Iter 73 Primal Discrepancies 0.04334146 R value 41.73141439
# Iter 74 Primal Discrepancies 0.03597459 R value 41.73075943
# Iter 75 Primal Discrepancies 0.02576275 R value 41.72987886
# Iter 76 Primal Discrepancies 0.01424042 R value 41.72890565
# Iter 77 Primal Discrepancies 0.00334248 R value 41.72796242
# Iter 78 Primal Discrepancies 0.00715984 R value 41.72714888
# Iter 79 Primal Discrepancies 0.01492521 R value 41.72653434
# Iter 80 Primal Discrepancies 0.01992447 R value 41.72615504
# Iter 81 Primal Discrepancies 0.02202317 R value 41.72601573
# Iter 82 Primal Discrepancies 0.02142268 R value 41.72609449
# Iter 83 Primal Discrepancies 0.01858746 R value 41.72634947
# Iter 84 Primal Discrepancies 0.01415490 R value 41.72672660
# Iter 85 Primal Discrepancies 0.00884017 R value 41.72716724
# Iter 86 Primal Discrepancies 0.00341898 R value 41.72761493
# Iter 87 Primal Discrepancies 0.00170407 R value 41.72802094
# Iter 88 Primal Discrepancies 0.00583378 R value 41.72834808
# Iter 89 Primal Discrepancies 0.00873067 R value 41.72857294
# Iter 90 Primal Discrepancies 0.01026159 R value 41.72868625
# Iter 91 Primal Discrepancies 0.01045963 R value 41.72869192
# Iter 92 Primal Discrepancies 0.00949660 R value 41.72860475
# Iter 93 Primal Discrepancies 0.00764461 R value 41.72844739
# Iter 94 Primal Discrepancies 0.00523259 R value 41.72824681
# Iter 95 Primal Discrepancies 0.00260272 R value 41.72803084
# Iter 96 Primal Discrepancies 0.00032009 R value 41.72782505
# Iter 97 Primal Discrepancies 0.00210040 R value 41.72765029
# Iter 98 Primal Discrepancies 0.00372935 R value 41.72752110
# Iter 99 Primal Discrepancies 0.00471684 R value 41.72744497
# Iter 100 Primal Discrepancies 0.00504848 R value 41.72742257
# Iter 101 Primal Discrepancies 0.00478331 R value 41.72744861
# Iter 102 Primal Discrepancies 0.00403681 R value 41.72751325
# Iter 103 Primal Discrepancies 0.00296011 R value 41.72760389
# Iter 104 Primal Discrepancies 0.00171833 R value 41.72770687
# Iter 105 Primal Discrepancies 0.00049106 R value 41.72780918
# Iter 106 Primal Discrepancies 0.00064666 R value 41.72789975
# Iter 107 Primal Discrepancies 0.00153088 R value 41.72797042
# Iter 108 Primal Discrepancies 0.00211991 R value 41.72801637
# Iter 109 Primal Discrepancies 0.00239277 R value 41.72803621
# Iter 110 Primal Discrepancies 0.00236590 R value 41.72803158
# Iter 111 Primal Discrepancies 0.00208592 R value 41.72800656
# Iter 112 Primal Discrepancies 0.00162017 R value 41.72796687
# Iter 113 Primal Discrepancies 0.00104633 R value 41.72791896
# Iter 114 Primal Discrepancies 0.00044474 R value 41.72786925
# Iter 115 Primal Discrepancies 0.00012378 R value 41.72782342
# Iter 116 Primal Discrepancies 0.00058979 R value 41.72778586
# Iter 117 Primal Discrepancies 0.00092591 R value 41.72775946
# Iter 118 Primal Discrepancies 0.00111250 R value 41.72774544
# Iter 119 Primal Discrepancies 0.00115111 R value 41.72774351
# Iter 120 Primal Discrepancies 0.00105914 R value 41.72775211
# Iter 121 Primal Discrepancies 0.00086560 R value 41.72776878
# Iter 122 Primal Discrepancies 0.00060630 R value 41.72779052
# Iter 123 Primal Discrepancies 0.00031898 R value 41.72781423
# Iter 124 Primal Discrepancies 0.00005625 R value 41.72783707
# Iter 125 Primal Discrepancies 0.00020461 R value 41.72785668
# Iter 126 Primal Discrepancies 0.00039045 R value 41.72787141
# Iter 127 Primal Discrepancies 0.00050684 R value 41.72788036
# Iter 128 Primal Discrepancies 0.00055127 R value 41.72788342
# Iter 129 Primal Discrepancies 0.00052939 R value 41.72788110
# Iter 130 Primal Discrepancies 0.00045324 R value 41.72787444
# Iter 131 Primal Discrepancies 0.00033896 R value 41.72786479
# Iter 132 Primal Discrepancies 0.00020453 R value 41.72785364
# Iter 133 Primal Discrepancies 0.00006910 R value 41.72784241
# Iter 134 Primal Discrepancies 0.00005699 R value 41.72783233
# Iter 135 Primal Discrepancies 0.00015712 R value 41.72782433
# Iter 136 Primal Discrepancies 0.00022562 R value 41.72781898
# Iter 137 Primal Discrepancies 0.00025965 R value 41.72781647
# Iter 138 Primal Discrepancies 0.00026053 R value 41.72781666
# Iter 139 Primal Discrepancies 0.00023299 R value 41.72781914
# Iter 140 Primal Discrepancies 0.00018416 R value 41.72782331
# Iter 141 Primal Discrepancies 0.00012245 R value 41.72782846
# Iter 142 Primal Discrepancies 0.00005642 R value 41.72783389
# Iter 143 Primal Discrepancies 0.00000896 R value 41.72783898
# Iter 144 Primal Discrepancies 0.00005887 R value 41.72784322
# Iter 145 Primal Discrepancies 0.00009756 R value 41.72784627
# Iter 146 Primal Discrepancies 0.00012002 R value 41.72784798
# Iter 147 Primal Discrepancies 0.00012617 R value 41.72784835
# Iter 148 Primal Discrepancies 0.00011773 R value 41.72784755
# Iter 149 Primal Discrepancies 0.00009774 R value 41.72784582
# Iter 150 Primal Discrepancies 0.00007004 R value 41.72784349
# Iter 151 Primal Discrepancies 0.00003877 R value 41.72784090
# Iter 152 Primal Discrepancies 0.00000894 R value 41.72783838
# Iter 153 Primal Discrepancies 0.00001942 R value 41.72783617
# Iter 154 Primal Discrepancies 0.00004061 R value 41.72783449
# Iter 155 Primal Discrepancies 0.00005430 R value 41.72783343
# Iter 156 Primal Discrepancies 0.00006011 R value 41.72783302
# Iter 157 Primal Discrepancies 0.00005854 R value 41.72783321
# Iter 158 Primal Discrepancies 0.00005085 R value 41.72783388
# Iter 159 Primal Discrepancies 0.00003875 R value 41.72783491
# Iter 160 Primal Discrepancies 0.00002421 R value 41.72783612
# Iter 161 Primal Discrepancies 0.00000928 R value 41.72783735
# Iter 162 Primal Discrepancies 0.00000469 R value 41.72783848
# Iter 163 Primal Discrepancies 0.00001602 R value 41.72783938
# Iter 164 Primal Discrepancies 0.00002396 R value 41.72784001
# Iter 165 Primal Discrepancies 0.00002814 R value 41.72784032
# Iter 166 Primal Discrepancies 0.00002865 R value 41.72784033
# Iter 167 Primal Discrepancies 0.00002598 R value 41.72784009
# Iter 168 Primal Discrepancies 0.00002088 R value 41.72783965
# Iter 169 Primal Discrepancies 0.00001426 R value 41.72783909
# Iter 170 Primal Discrepancies 0.00000705 R value 41.72783850
# Iter 171 Primal Discrepancies 0.00000084 R value 41.72783794
# Iter 172 Primal Discrepancies 0.00000581 R value 41.72783746
# Iter 173 Primal Discrepancies 0.00001024 R value 41.72783711
# Iter 174 Primal Discrepancies 0.00001292 R value 41.72783690
# Iter 175 Primal Discrepancies 0.00001380 R value 41.72783685
# Iter 176 Primal Discrepancies 0.00001306 R value 41.72783692
# Iter 177 Primal Discrepancies 0.00001101 R value 41.72783710
# Iter 178 Primal Discrepancies 0.00000806 R value 41.72783735
# Iter 179 Primal Discrepancies 0.00000466 R value 41.72783763
# Iter 180 Primal Discrepancies 0.00000132 R value 41.72783791
# Iter 181 Primal Discrepancies 0.00000179 R value 41.72783815
# Iter 182 Primal Discrepancies 0.00000420 R value 41.72783834
# Iter 183 Primal Discrepancies 0.00000580 R value 41.72783847
# Iter 184 Primal Discrepancies 0.00000654 R value 41.72783852
# Iter 185 Primal Discrepancies 0.00000646 R value 41.72783851
# Iter 186 Primal Discrepancies 0.00000569 R value 41.72783844
# Iter 187 Primal Discrepancies 0.00000442 R value 41.72783833
# Iter 188 Primal Discrepancies 0.00000285 R value 41.72783820
# Iter 189 Primal Discrepancies 0.00000120 R value 41.72783807
# Iter 190 Primal Discrepancies 0.00000035 R value 41.72783794
# Iter 191 Primal Discrepancies 0.00000162 R value 41.72783784
# Iter 192 Primal Discrepancies 0.00000254 R value 41.72783777
# Iter 193 Primal Discrepancies 0.00000304 R value 41.72783773
# Iter 194 Primal Discrepancies 0.00000315 R value 41.72783772
# Iter 195 Primal Discrepancies 0.00000289 R value 41.72783775
# Iter 196 Primal Discrepancies 0.00000236 R value 41.72783779
# Iter 197 Primal Discrepancies 0.00000165 R value 41.72783785
# Iter 198 Primal Discrepancies 0.00000087 R value 41.72783792
# Iter 199 Primal Discrepancies 0.00000015 R value 41.72783798
# Iter 200 Primal Discrepancies 0.00000056 R value 41.72783803
# Iter 201 Primal Discrepancies 0.00000107 R value 41.72783807
# Iter 202 Primal Discrepancies 0.00000139 R value 41.72783810
# Iter 203 Primal Discrepancies 0.00000151 R value 41.72783811
# Iter 204 Primal Discrepancies 0.00000145 R value 41.72783810
# Iter 205 Primal Discrepancies 0.00000124 R value 41.72783808
# Iter 206 Primal Discrepancies 0.00000092 R value 41.72783805
# Iter 207 Primal Discrepancies 0.00000056 R value 41.72783802
# Iter 208 Primal Discrepancies 0.00000019 R value 41.72783799
# Iter 209 Primal Discrepancies 0.00000016 R value 41.72783797
# Iter 210 Primal Discrepancies 0.00000043 R value 41.72783794
# Iter 211 Primal Discrepancies 0.00000062 R value 41.72783793
# Iter 212 Primal Discrepancies 0.00000071 R value 41.72783792
# Iter 213 Primal Discrepancies 0.00000071 R value 41.72783792
# Iter 214 Primal Discrepancies 0.00000064 R value 41.72783793
# Iter 215 Primal Discrepancies 0.00000050 R value 41.72783794
# Iter 216 Primal Discrepancies 0.00000033 R value 41.72783796
# Iter 217 Primal Discrepancies 0.00000015 R value 41.72783797
# Iter 218 Primal Discrepancies 0.00000002 R value 41.72783798
# Iter 219 Primal Discrepancies 0.00000016 R value 41.72783800
# Iter 220 Primal Discrepancies 0.00000027 R value 41.72783800
# Iter 221 Primal Discrepancies 0.00000033 R value 41.72783801
# Iter 222 Primal Discrepancies 0.00000034 R value 41.72783801
# Iter 223 Primal Discrepancies 0.00000032 R value 41.72783801
# Iter 224 Primal Discrepancies 0.00000027 R value 41.72783800
# Iter 225 Primal Discrepancies 0.00000019 R value 41.72783800
# Iter 226 Primal Discrepancies 0.00000011 R value 41.72783799
# Iter 227 Primal Discrepancies 0.00000002 R value 41.72783798
# Stopping at iteration 227
# X = 24.582120472961627
# Y = 25.413558275880554
# R = 41.72783798290298
# Correct values are:
# X = 24.58212046374567
# Y = 25.41355826361457
# R = 41.7278379893865

# %%
##QP_ADMM for 4 selected circles in n=10, m=100 test case

using JuMP
using Printf
import Juniper
import Ipopt

a = [13.239512466541303, 41.55335924184264, 43.70990076229758, 13.150886893355297] # x-cordinates of selected circle
b = [43.945805488954605, 31.204816928920724, 15.106911655793608, 11.789181775998983] # y-cordinates of selected circle
r = [20, 20, 20, 20 ] # Radius of selected cirlcles
   

NumVar = size(r)[1] 

rho = 1.0  ### Augmented Lagrangian penalty coefficient
  ## Note: rho may be allowed to vary under restriction


## Typing of parameters is optional, but wise.
## Form the AL primal subproblem
function solveSP(i::Int64, vdual::Dict{String,Float64}, X::Float64,Y::Float64, R::Float64 )

  model = Model(
        optimizer_with_attributes(
            #Juniper.Optimizer,
            #"nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
            #    MOI.Silent() => true,
            #),
        ),
    )
    set_optimizer_attribute(model, "print_level", 0)  ### Suppress Ipopt output
    set_optimizer_attribute(model, "tol", 1e-14)  ### Not required in general

    @variable(model, x )
    @variable(model, y )
    @variable(model, z >= 0)
  
    ### primal objective + Lagrange terms + augmented (squared penalty) terms
    @objective(model, Min, z+r[i] 
	+ vdual["x"]*(x + X - a[i]) + vdual["y"]*(y + Y - b[i]) + vdual["z"]*(z + r[i] - R)
	+ 0.5*rho*( (x+X-a[i])^2 + (y+Y-b[i])^2 + (z+r[i]-R)^2 ) )

    ### All coupling constraints are relaxed.
    @constraint( model, xyz, x^2 + y^2 <= z^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
  ## Initialization
    x = Dict{Int64,Float64}()
    y = Dict{Int64,Float64}()
    z = Dict{Int64,Float64}()

    ### Initialize Lagrangian multipliers to zero value
    vdual = Dict{Int64, Dict{String,Float64}}()
    for i in 1:NumVar
	vdual[i] = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    end

    X,Y,R=0.0,0.0,0.0
    oldX,oldY,oldR=0.0,0.0,0.0
    ### Initialize R to average of r[i], i=1,...,n
    for i in 1:length(a)
	R += (1.0/NumVar)*(r[i])
    end
  ## End of initialization

for n in 1:1000
    ### Solve AL subproblem for each subproblem i with X,Y,R fixed
    for i in 1:NumVar
      x[i],y[i],z[i] = solveSP(i,vdual[i],X,Y,R)
    end

    ### Subproblems in X,Y,R (with x,y,z fixed) can be solved in closed-form
    oldX,oldY,oldR=X,Y,R
    X,Y,R=0.0,0.0,0.0
    for i in 1:NumVar
	X += (1.0/NumVar)*(a[i]-x[i])
	Y += (1.0/NumVar)*(b[i]-y[i])
	R += (1.0/NumVar)*(z[i]+r[i])
    end

    ### Update Lagrange multipliers, compute a measure of primal infeasibility.
    discr = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    for i in 1:NumVar
	vdual[i]["x"] += rho*(x[i] + X - a[i]) 
	vdual[i]["y"] += rho*(y[i] + Y - b[i]) 
	vdual[i]["z"] += rho*(z[i] + r[i] - R)

	discr["x"] += abs(x[i] + X - a[i])
	discr["y"] += abs(y[i] + Y - b[i])
	discr["z"] += abs(z[i] + r[i] - R)
    end
    @printf("Iter %d Primal Discrepancies %8.8f R value %8.8f\n", 
	n, discr["x"] + discr["y"] + discr["z"], R)
    d_discr = abs(X-oldX)+abs(Y-oldY)+abs(R-oldR) ### Dual residues
    if discr["x"] + discr["y"] + discr["z"] + d_discr < 1e-7
	println("Stopping at iteration ",n)  ### Primal feasible within tolerance
	break
    end
end
    @show(X)
    @show(Y)
    @show(R)

println("Correct values are: ")

println("X = ",26.868995309890536)
println("Y = ",27.829807823090338)
println("R = ",41.1065909982292)
end

main()
# Out:
# Iter 1 Primal Discrepancies 76.98261271 R value 39.72135665
# Iter 2 Primal Discrepancies 14.80626207 R value 47.97197368
# Iter 3 Primal Discrepancies 37.32830971 R value 50.64658934
# Iter 4 Primal Discrepancies 23.67589522 R value 50.09443235
# Iter 5 Primal Discrepancies 6.16034356 R value 49.09443235
# Iter 6 Primal Discrepancies 0.00000000 R value 48.09443235
# Iter 7 Primal Discrepancies 0.00000000 R value 47.09443235
# Iter 8 Primal Discrepancies 0.00000000 R value 46.09443235
# Iter 9 Primal Discrepancies 0.00000000 R value 45.09443235
# Iter 10 Primal Discrepancies 1.43927397 R value 44.20135298
# Iter 11 Primal Discrepancies 2.54472106 R value 43.64747754
# Iter 12 Primal Discrepancies 2.48028700 R value 43.40911201
# Iter 13 Primal Discrepancies 1.78938782 R value 43.32020003
# Iter 14 Primal Discrepancies 1.51733579 R value 43.24131245
# Iter 15 Primal Discrepancies 1.11110271 R value 43.17494542
# Iter 16 Primal Discrepancies 1.00255863 R value 43.13811256
# Iter 17 Primal Discrepancies 0.81589395 R value 43.08882651
# Iter 18 Primal Discrepancies 0.66958008 R value 43.00419267
# Iter 19 Primal Discrepancies 0.44711569 R value 42.88060119
# Iter 20 Primal Discrepancies 0.29745722 R value 42.72862779
# Iter 21 Primal Discrepancies 0.28203388 R value 42.56563503
# Iter 22 Primal Discrepancies 0.42753431 R value 42.40881748
# Iter 23 Primal Discrepancies 0.49287011 R value 42.27044122
# Iter 24 Primal Discrepancies 0.44014509 R value 42.15588814
# Iter 25 Primal Discrepancies 0.32754937 R value 42.06416863
# Iter 26 Primal Discrepancies 0.19975106 R value 41.99000438
# Iter 27 Primal Discrepancies 0.15693971 R value 41.92644065
# Iter 28 Primal Discrepancies 0.19754851 R value 41.86712945
# Iter 29 Primal Discrepancies 0.20139945 R value 41.80777767
# Iter 30 Primal Discrepancies 0.17656446 R value 41.74662865
# Iter 31 Primal Discrepancies 0.12195727 R value 41.68413756
# Iter 32 Primal Discrepancies 0.07290351 R value 41.62216165
# Iter 33 Primal Discrepancies 0.07011170 R value 41.56301612
# Iter 34 Primal Discrepancies 0.10395959 R value 41.50867829
# Iter 35 Primal Discrepancies 0.12050248 R value 41.46030313
# Iter 36 Primal Discrepancies 0.11412357 R value 41.41808700
# Iter 37 Primal Discrepancies 0.09450143 R value 41.38141771
# Iter 38 Primal Discrepancies 0.07215990 R value 41.34919349
# Iter 39 Primal Discrepancies 0.05921701 R value 41.32018328
# Iter 40 Primal Discrepancies 0.06139433 R value 41.29332558
# Iter 41 Primal Discrepancies 0.06236809 R value 41.26790655
# Iter 42 Primal Discrepancies 0.05833258 R value 41.24360478
# Iter 43 Primal Discrepancies 0.05101938 R value 41.22042712
# Iter 44 Primal Discrepancies 0.04254377 R value 41.19858078
# Iter 45 Primal Discrepancies 0.04023040 R value 41.17833084
# Iter 46 Primal Discrepancies 0.04178706 R value 41.15988290
# Iter 47 Primal Discrepancies 0.04361543 R value 41.14331377
# Iter 48 Primal Discrepancies 0.04188818 R value 41.12855492
# Iter 49 Primal Discrepancies 0.03753635 R value 41.11541908
# Iter 50 Primal Discrepancies 0.03354173 R value 41.10365188
# Iter 51 Primal Discrepancies 0.18168721 R value 41.10664098
# Iter 52 Primal Discrepancies 0.29705669 R value 41.12499460
# Iter 53 Primal Discrepancies 0.36404678 R value 41.15029678
# Iter 54 Primal Discrepancies 0.41365527 R value 41.17210989
# Iter 55 Primal Discrepancies 0.43052348 R value 41.18316617
# Iter 56 Primal Discrepancies 0.40198982 R value 41.18133199
# Iter 57 Primal Discrepancies 0.33642548 R value 41.16882514
# Iter 58 Primal Discrepancies 0.24629699 R value 41.15008432
# Iter 59 Primal Discrepancies 0.14497876 R value 41.12965591
# Iter 60 Primal Discrepancies 0.05246686 R value 41.11089036
# Iter 61 Primal Discrepancies 0.04646925 R value 41.09558956
# Iter 62 Primal Discrepancies 0.11935813 R value 41.08431472
# Iter 63 Primal Discrepancies 0.17207482 R value 41.07693379
# Iter 64 Primal Discrepancies 0.20236984 R value 41.07308183
# Iter 65 Primal Discrepancies 0.21062242 R value 41.07239246
# Iter 66 Primal Discrepancies 0.19895577 R value 41.07452083
# Iter 67 Primal Discrepancies 0.17091904 R value 41.07906127
# Iter 68 Primal Discrepancies 0.13108110 R value 41.08546719
# Iter 69 Primal Discrepancies 0.08453826 R value 41.09303613
# Iter 70 Primal Discrepancies 0.03638616 R value 41.10096899
# Iter 71 Primal Discrepancies 0.00961090 R value 41.10847424
# Iter 72 Primal Discrepancies 0.04720694 R value 41.11487565
# Iter 73 Primal Discrepancies 0.07631527 R value 41.11969092
# Iter 74 Primal Discrepancies 0.09469836 R value 41.12266646
# Iter 75 Primal Discrepancies 0.10212189 R value 41.12377094
# Iter 76 Primal Discrepancies 0.09936736 R value 41.12316009
# Iter 77 Primal Discrepancies 0.08801852 R value 41.12112736
# Iter 78 Primal Discrepancies 0.07021289 R value 41.11805210
# Iter 79 Primal Discrepancies 0.04838357 R value 41.11435165
# Iter 80 Primal Discrepancies 0.02501074 R value 41.11044025
# Iter 81 Primal Discrepancies 0.00509288 R value 41.10669504
# Iter 82 Primal Discrepancies 0.01750477 R value 41.10342954
# Iter 83 Primal Discrepancies 0.03324424 R value 41.10087485
# Iter 84 Primal Discrepancies 0.04392555 R value 41.09916946
# Iter 85 Primal Discrepancies 0.04923093 R value 41.09835791
# Iter 86 Primal Discrepancies 0.04937582 R value 41.09839811
# Iter 87 Primal Discrepancies 0.04502070 R value 41.09917586
# Iter 88 Primal Discrepancies 0.03715171 R value 41.10052446
# Iter 89 Primal Discrepancies 0.02694604 R value 41.10224693
# Iter 90 Primal Discrepancies 0.01563779 R value 41.10413806
# Iter 91 Primal Discrepancies 0.00452991 R value 41.10600435
# Iter 92 Primal Discrepancies 0.00576786 R value 41.10768008
# Iter 93 Primal Discrepancies 0.01407999 R value 41.10903859
# Iter 94 Primal Discrepancies 0.02003225 R value 41.10999856
# Iter 95 Primal Discrepancies 0.02339688 R value 41.11052530
# Iter 96 Primal Discrepancies 0.02420869 R value 41.11062771
# Iter 97 Primal Discrepancies 0.02272743 R value 41.11035186
# Iter 98 Primal Discrepancies 0.01938528 R value 41.10977192
# Iter 99 Primal Discrepancies 0.01472585 R value 41.10897993
# Iter 100 Primal Discrepancies 0.00934118 R value 41.10807512
# Iter 101 Primal Discrepancies 0.00381221 R value 41.10715404
# Iter 102 Primal Discrepancies 0.00137419 R value 41.10630216
# Iter 103 Primal Discrepancies 0.00570381 R value 41.10558758
# Iter 104 Primal Discrepancies 0.00898091 R value 41.10505708
# Iter 105 Primal Discrepancies 0.01101763 R value 41.10473467
# Iter 106 Primal Discrepancies 0.01179102 R value 41.10462239
# Iter 107 Primal Discrepancies 0.01139578 R value 41.10470296
# Iter 108 Primal Discrepancies 0.01002029 R value 41.10494392
# Iter 109 Primal Discrepancies 0.00791725 R value 41.10530250
# Iter 110 Primal Discrepancies 0.00537222 R value 41.10573090
# Iter 111 Primal Discrepancies 0.00267342 R value 41.10618124
# Iter 112 Primal Discrepancies 0.00047323 R value 41.10660991
# Iter 113 Primal Discrepancies 0.00217269 R value 41.10698094
# Iter 114 Primal Discrepancies 0.00393922 R value 41.10726830
# Iter 115 Primal Discrepancies 0.00511882 R value 41.10745689
# Iter 116 Primal Discrepancies 0.00568145 R value 41.10754255
# Iter 117 Primal Discrepancies 0.00565675 R value 41.10753094
# Iter 118 Primal Discrepancies 0.00512358 R value 41.10743580
# Iter 119 Primal Discrepancies 0.00419644 R value 41.10727664
# Iter 120 Primal Discrepancies 0.00301056 R value 41.10707620
# Iter 121 Primal Discrepancies 0.00170693 R value 41.10685801
# Iter 122 Primal Discrepancies 0.00045565 R value 41.10664413
# Iter 123 Primal Discrepancies 0.00073919 R value 41.10645335
# Iter 124 Primal Discrepancies 0.00167929 R value 41.10629992
# Iter 125 Primal Discrepancies 0.00234480 R value 41.10619284
# Iter 126 Primal Discrepancies 0.00271129 R value 41.10613577
# Iter 127 Primal Discrepancies 0.00278459 R value 41.10612734
# Iter 128 Primal Discrepancies 0.00259632 R value 41.10616197
# Iter 129 Primal Discrepancies 0.00219765 R value 41.10623090
# Iter 130 Primal Discrepancies 0.00165213 R value 41.10632342
# Iter 131 Primal Discrepancies 0.00102830 R value 41.10642808
# Iter 132 Primal Discrepancies 0.00039282 R value 41.10653383
# Iter 133 Primal Discrepancies 0.00019526 R value 41.10663096
# Iter 134 Primal Discrepancies 0.00068894 R value 41.10671179
# Iter 135 Primal Discrepancies 0.00105587 R value 41.10677116
# Iter 136 Primal Discrepancies 0.00127938 R value 41.10680647
# Iter 137 Primal Discrepancies 0.00135797 R value 41.10681768
# Iter 138 Primal Discrepancies 0.00130344 R value 41.10680692
# Iter 139 Primal Discrepancies 0.00113809 R value 41.10677802
# Iter 140 Primal Discrepancies 0.00089133 R value 41.10673597
# Iter 141 Primal Discrepancies 0.00059611 R value 41.10668629
# Iter 142 Primal Discrepancies 0.00028547 R value 41.10663446
# Iter 143 Primal Discrepancies 0.00004874 R value 41.10658547
# Iter 144 Primal Discrepancies 0.00026689 R value 41.10654336
# Iter 145 Primal Discrepancies 0.00046568 R value 41.10651106
# Iter 146 Primal Discrepancies 0.00059641 R value 41.10649021
# Iter 147 Primal Discrepancies 0.00065610 R value 41.10648119
# Iter 148 Primal Discrepancies 0.00064864 R value 41.10648329
# Iter 149 Primal Discrepancies 0.00058346 R value 41.10649486
# Iter 150 Primal Discrepancies 0.00047398 R value 41.10651362
# Iter 151 Primal Discrepancies 0.00033590 R value 41.10653693
# Iter 152 Primal Discrepancies 0.00018544 R value 41.10656210
# Iter 153 Primal Discrepancies 0.00004628 R value 41.10658659
# Iter 154 Primal Discrepancies 0.00009394 R value 41.10660829
# Iter 155 Primal Discrepancies 0.00020002 R value 41.10662559
# Iter 156 Primal Discrepancies 0.00027416 R value 41.10663750
# Iter 157 Primal Discrepancies 0.00031382 R value 41.10664365
# Iter 158 Primal Discrepancies 0.00031991 R value 41.10664423
# Iter 159 Primal Discrepancies 0.00029626 R value 41.10663992
# Iter 160 Primal Discrepancies 0.00024889 R value 41.10663175
# Iter 161 Primal Discrepancies 0.00018517 R value 41.10662095
# Iter 162 Primal Discrepancies 0.00011302 R value 41.10660885
# Iter 163 Primal Discrepancies 0.00004005 R value 41.10659671
# Iter 164 Primal Discrepancies 0.00002703 R value 41.10658564
# Iter 165 Primal Discrepancies 0.00008290 R value 41.10657650
# Iter 166 Primal Discrepancies 0.00012399 R value 41.10656986
# Iter 167 Primal Discrepancies 0.00014849 R value 41.10656600
# Iter 168 Primal Discrepancies 0.00015637 R value 41.10656490
# Iter 169 Primal Discrepancies 0.00014906 R value 41.10656631
# Iter 170 Primal Discrepancies 0.00012922 R value 41.10656977
# Iter 171 Primal Discrepancies 0.00010028 R value 41.10657470
# Iter 172 Primal Discrepancies 0.00006604 R value 41.10658045
# Iter 173 Primal Discrepancies 0.00003029 R value 41.10658641
# Iter 174 Primal Discrepancies 0.00000607 R value 41.10659201
# Iter 175 Primal Discrepancies 0.00003263 R value 41.10659679
# Iter 176 Primal Discrepancies 0.00005498 R value 41.10660041
# Iter 177 Primal Discrepancies 0.00006943 R value 41.10660271
# Iter 178 Primal Discrepancies 0.00007572 R value 41.10660365
# Iter 179 Primal Discrepancies 0.00007433 R value 41.10660333
# Iter 180 Primal Discrepancies 0.00006640 R value 41.10660192
# Iter 181 Primal Discrepancies 0.00005350 R value 41.10659972
# Iter 182 Primal Discrepancies 0.00003743 R value 41.10659701
# Iter 183 Primal Discrepancies 0.00002008 R value 41.10659411
# Iter 184 Primal Discrepancies 0.00000462 R value 41.10659130
# Iter 185 Primal Discrepancies 0.00001181 R value 41.10658884
# Iter 186 Primal Discrepancies 0.00002378 R value 41.10658689
# Iter 187 Primal Discrepancies 0.00003203 R value 41.10658556
# Iter 188 Primal Discrepancies 0.00003630 R value 41.10658490
# Iter 189 Primal Discrepancies 0.00003674 R value 41.10658488
# Iter 190 Primal Discrepancies 0.00003379 R value 41.10658541
# Iter 191 Primal Discrepancies 0.00002817 R value 41.10658638
# Iter 192 Primal Discrepancies 0.00002073 R value 41.10658764
# Iter 193 Primal Discrepancies 0.00001239 R value 41.10658904
# Iter 194 Primal Discrepancies 0.00000403 R value 41.10659043
# Iter 195 Primal Discrepancies 0.00000363 R value 41.10659169
# Iter 196 Primal Discrepancies 0.00000995 R value 41.10659272
# Iter 197 Primal Discrepancies 0.00001454 R value 41.10659347
# Iter 198 Primal Discrepancies 0.00001722 R value 41.10659389
# Iter 199 Primal Discrepancies 0.00001799 R value 41.10659399
# Iter 200 Primal Discrepancies 0.00001704 R value 41.10659381
# Iter 201 Primal Discrepancies 0.00001466 R value 41.10659340
# Iter 202 Primal Discrepancies 0.00001127 R value 41.10659282
# Iter 203 Primal Discrepancies 0.00000730 R value 41.10659215
# Iter 204 Primal Discrepancies 0.00000319 R value 41.10659147
# Iter 205 Primal Discrepancies 0.00000081 R value 41.10659083
# Iter 206 Primal Discrepancies 0.00000397 R value 41.10659029
# Iter 207 Primal Discrepancies 0.00000648 R value 41.10658988
# Iter 208 Primal Discrepancies 0.00000808 R value 41.10658963
# Iter 209 Primal Discrepancies 0.00000873 R value 41.10658953
# Iter 210 Primal Discrepancies 0.00000851 R value 41.10658958
# Iter 211 Primal Discrepancies 0.00000755 R value 41.10658975
# Iter 212 Primal Discrepancies 0.00000603 R value 41.10659001
# Iter 213 Primal Discrepancies 0.00000417 R value 41.10659032
# Iter 214 Primal Discrepancies 0.00000217 R value 41.10659066
# Iter 215 Primal Discrepancies 0.00000045 R value 41.10659098
# Iter 216 Primal Discrepancies 0.00000147 R value 41.10659126
# Iter 217 Primal Discrepancies 0.00000282 R value 41.10659148
# Iter 218 Primal Discrepancies 0.00000374 R value 41.10659162
# Iter 219 Primal Discrepancies 0.00000420 R value 41.10659169
# Iter 220 Primal Discrepancies 0.00000422 R value 41.10659169
# Iter 221 Primal Discrepancies 0.00000385 R value 41.10659163
# Iter 222 Primal Discrepancies 0.00000319 R value 41.10659151
# Iter 223 Primal Discrepancies 0.00000232 R value 41.10659137
# Iter 224 Primal Discrepancies 0.00000136 R value 41.10659120
# Iter 225 Primal Discrepancies 0.00000040 R value 41.10659104
# Iter 226 Primal Discrepancies 0.00000048 R value 41.10659090
# Iter 227 Primal Discrepancies 0.00000119 R value 41.10659078
# Iter 228 Primal Discrepancies 0.00000170 R value 41.10659070
# Iter 229 Primal Discrepancies 0.00000200 R value 41.10659066
# Iter 230 Primal Discrepancies 0.00000207 R value 41.10659065
# Iter 231 Primal Discrepancies 0.00000195 R value 41.10659067
# Iter 232 Primal Discrepancies 0.00000166 R value 41.10659072
# Iter 233 Primal Discrepancies 0.00000127 R value 41.10659079
# Iter 234 Primal Discrepancies 0.00000081 R value 41.10659086
# Iter 235 Primal Discrepancies 0.00000033 R value 41.10659094
# Iter 236 Primal Discrepancies 0.00000011 R value 41.10659101
# Iter 237 Primal Discrepancies 0.00000048 R value 41.10659108
# Iter 238 Primal Discrepancies 0.00000076 R value 41.10659112
# Iter 239 Primal Discrepancies 0.00000094 R value 41.10659115
# Iter 240 Primal Discrepancies 0.00000101 R value 41.10659116
# Iter 241 Primal Discrepancies 0.00000097 R value 41.10659115
# Iter 242 Primal Discrepancies 0.00000086 R value 41.10659113
# Iter 243 Primal Discrepancies 0.00000068 R value 41.10659110
# Iter 244 Primal Discrepancies 0.00000046 R value 41.10659106
# Iter 245 Primal Discrepancies 0.00000023 R value 41.10659103
# Iter 246 Primal Discrepancies 0.00000004 R value 41.10659099
# Iter 247 Primal Discrepancies 0.00000018 R value 41.10659096
# Iter 248 Primal Discrepancies 0.00000033 R value 41.10659093
# Iter 249 Primal Discrepancies 0.00000044 R value 41.10659092
# Iter 250 Primal Discrepancies 0.00000048 R value 41.10659091
# Iter 251 Primal Discrepancies 0.00000048 R value 41.10659091
# Iter 252 Primal Discrepancies 0.00000044 R value 41.10659092
# Iter 253 Primal Discrepancies 0.00000036 R value 41.10659093
# Iter 254 Primal Discrepancies 0.00000026 R value 41.10659095
# Iter 255 Primal Discrepancies 0.00000015 R value 41.10659097
# Iter 256 Primal Discrepancies 0.00000004 R value 41.10659099
# Iter 257 Primal Discrepancies 0.00000006 R value 41.10659100
# Iter 258 Primal Discrepancies 0.00000014 R value 41.10659102
# Iter 259 Primal Discrepancies 0.00000020 R value 41.10659102
# Iter 260 Primal Discrepancies 0.00000023 R value 41.10659103
# Iter 261 Primal Discrepancies 0.00000024 R value 41.10659103
# Iter 262 Primal Discrepancies 0.00000022 R value 41.10659103
# Iter 263 Primal Discrepancies 0.00000019 R value 41.10659102
# Iter 264 Primal Discrepancies 0.00000014 R value 41.10659101
# Iter 265 Primal Discrepancies 0.00000009 R value 41.10659100
# Iter 266 Primal Discrepancies 0.00000003 R value 41.10659100
# Stopping at iteration 266
# X = 26.868995334832594
# Y = 27.829807848858845
# R = 41.10659099575169
# Correct values are:
# X = 26.868995309890536
# Y = 27.829807823090338
# R = 41.1065909982292

# %%
##QP_ADMM for 3 selected circles in n=20, m=25 test case

using JuMP
using Printf
import Juniper
import Ipopt

a = [49.42043424128368, 31.611086580497098,  12.419857083265606] # x-cordinates of selected circle
b = [ 44.79128960675432, 19.19929956530496, 28.300299268064713] # y-cordinates of selected circle
r = [20, 20, 20 ] # Radius of selected cirlcles
   
   

NumVar = size(r)[1] 

rho = 1.0  ### Augmented Lagrangian penalty coefficient
  ## Note: rho may be allowed to vary under restriction


## Typing of parameters is optional, but wise.
## Form the AL primal subproblem
function solveSP(i::Int64, vdual::Dict{String,Float64}, X::Float64,Y::Float64, R::Float64 )

  model = Model(
        optimizer_with_attributes(
            #Juniper.Optimizer,
            #"nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
            #    MOI.Silent() => true,
            #),
        ),
    )
    set_optimizer_attribute(model, "print_level", 0)  ### Suppress Ipopt output
    set_optimizer_attribute(model, "tol", 1e-14)  ### Not required in general

    @variable(model, x )
    @variable(model, y )
    @variable(model, z >= 0)
  
    ### primal objective + Lagrange terms + augmented (squared penalty) terms
    @objective(model, Min, z+r[i] 
	+ vdual["x"]*(x + X - a[i]) + vdual["y"]*(y + Y - b[i]) + vdual["z"]*(z + r[i] - R)
	+ 0.5*rho*( (x+X-a[i])^2 + (y+Y-b[i])^2 + (z+r[i]-R)^2 ) )

    ### All coupling constraints are relaxed.
    @constraint( model, xyz, x^2 + y^2 <= z^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
  ## Initialization
    x = Dict{Int64,Float64}()
    y = Dict{Int64,Float64}()
    z = Dict{Int64,Float64}()

    ### Initialize Lagrangian multipliers to zero value
    vdual = Dict{Int64, Dict{String,Float64}}()
    for i in 1:NumVar
	vdual[i] = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    end

    X,Y,R=0.0,0.0,0.0
    oldX,oldY,oldR=0.0,0.0,0.0
    ### Initialize R to average of r[i], i=1,...,n
    for i in 1:length(a)
	R += (1.0/NumVar)*(r[i])
    end
  ## End of initialization

for n in 1:1000
    ### Solve AL subproblem for each subproblem i with X,Y,R fixed
    for i in 1:NumVar
      x[i],y[i],z[i] = solveSP(i,vdual[i],X,Y,R)
    end

    ### Subproblems in X,Y,R (with x,y,z fixed) can be solved in closed-form
    oldX,oldY,oldR=X,Y,R
    X,Y,R=0.0,0.0,0.0
    for i in 1:NumVar
	X += (1.0/NumVar)*(a[i]-x[i])
	Y += (1.0/NumVar)*(b[i]-y[i])
	R += (1.0/NumVar)*(z[i]+r[i])
    end

    ### Update Lagrange multipliers, compute a measure of primal infeasibility.
    discr = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    for i in 1:NumVar
	vdual[i]["x"] += rho*(x[i] + X - a[i]) 
	vdual[i]["y"] += rho*(y[i] + Y - b[i]) 
	vdual[i]["z"] += rho*(z[i] + r[i] - R)

	discr["x"] += abs(x[i] + X - a[i])
	discr["y"] += abs(y[i] + Y - b[i])
	discr["z"] += abs(z[i] + r[i] - R)
    end
    @printf("Iter %d Primal Discrepancies %8.8f R value %8.8f\n", 
	n, discr["x"] + discr["y"] + discr["z"], R)
    d_discr = abs(X-oldX)+abs(Y-oldY)+abs(R-oldR) ### Dual residues
    if discr["x"] + discr["y"] + discr["z"] + d_discr < 1e-7
	println("Stopping at iteration ",n)  ### Primal feasible within tolerance
	break
    end
end
    @show(X)
    @show(Y)
    @show(R)

println("Correct values are: ")

println("X = ",30.920145668409557)
println("Y = ",36.54579442364673)
println("R = ",40.254601163366)
end

main()
# Out:
# Iter 1 Primal Discrepancies 54.82693714 R value 41.93142613
# Iter 2 Primal Discrepancies 28.68245640 R value 48.57508480
# Iter 3 Primal Discrepancies 9.84631065 R value 54.19366122
# Iter 4 Primal Discrepancies 26.24570954 R value 57.08953309
# Iter 5 Primal Discrepancies 28.41912126 R value 57.03833444
# Iter 6 Primal Discrepancies 9.15019189 R value 56.03833444
# Iter 7 Primal Discrepancies 0.00000000 R value 55.03833444
# Iter 8 Primal Discrepancies 0.00000000 R value 54.03833444
# Iter 9 Primal Discrepancies 0.00000000 R value 53.03833444
# Iter 10 Primal Discrepancies 0.00000000 R value 52.03833444
# Iter 11 Primal Discrepancies 0.00000000 R value 51.03833444
# Iter 12 Primal Discrepancies 0.00000000 R value 50.03833444
# Iter 13 Primal Discrepancies 0.00000000 R value 49.03833444
# Iter 14 Primal Discrepancies 0.00000000 R value 48.03833444
# Iter 15 Primal Discrepancies 0.00000000 R value 47.03833444
# Iter 16 Primal Discrepancies 0.00000000 R value 46.03833444
# Iter 17 Primal Discrepancies 0.34032453 R value 45.07362271
# Iter 18 Primal Discrepancies 1.72079597 R value 44.28734040
# Iter 19 Primal Discrepancies 2.06751161 R value 43.71543847
# Iter 20 Primal Discrepancies 1.60948483 R value 43.31042411
# Iter 21 Primal Discrepancies 0.76763870 R value 42.98500625
# Iter 22 Primal Discrepancies 0.04947162 R value 42.65445867
# Iter 23 Primal Discrepancies 0.57772129 R value 42.26400714
# Iter 24 Primal Discrepancies 0.73731398 R value 41.79710349
# Iter 25 Primal Discrepancies 0.59552250 R value 41.27842107
# Iter 26 Primal Discrepancies 1.36603632 R value 40.88613770
# Iter 27 Primal Discrepancies 1.75025663 R value 40.68916075
# Iter 28 Primal Discrepancies 1.45853180 R value 40.66345888
# Iter 29 Primal Discrepancies 0.78562503 R value 40.73510942
# Iter 30 Primal Discrepancies 0.13176269 R value 40.82461402
# Iter 31 Primal Discrepancies 0.40705009 R value 40.87651536
# Iter 32 Primal Discrepancies 0.58525352 R value 40.86973983
# Iter 33 Primal Discrepancies 0.50230669 R value 40.81234881
# Iter 34 Primal Discrepancies 0.27036831 R value 40.72821591
# Iter 35 Primal Discrepancies 0.04225928 R value 40.64309635
# Iter 36 Primal Discrepancies 0.16768666 R value 40.57504921
# Iter 37 Primal Discrepancies 0.24301716 R value 40.53090719
# Iter 38 Primal Discrepancies 0.22083848 R value 40.50782752
# Iter 39 Primal Discrepancies 0.14101468 R value 40.49758563
# Iter 40 Primal Discrepancies 0.04783943 R value 40.49118599
# Iter 41 Primal Discrepancies 0.04458136 R value 40.48212248
# Iter 42 Primal Discrepancies 0.06803471 R value 40.46766424
# Iter 43 Primal Discrepancies 0.06442217 R value 40.44842454
# Iter 44 Primal Discrepancies 0.04590695 R value 40.42695500
# Iter 45 Primal Discrepancies 0.02437220 R value 40.40617557
# Iter 46 Primal Discrepancies 0.02848834 R value 40.38822392
# Iter 47 Primal Discrepancies 0.03984246 R value 40.37396578
# Iter 48 Primal Discrepancies 0.03929525 R value 40.36310299
# Iter 49 Primal Discrepancies 0.02985534 R value 40.35463802
# Iter 50 Primal Discrepancies 0.01918377 R value 40.34741718
# Iter 51 Primal Discrepancies 0.01366408 R value 40.34054385
# Iter 52 Primal Discrepancies 0.01633047 R value 40.33356735
# Iter 53 Primal Discrepancies 0.01643657 R value 40.32646056
# Iter 54 Primal Discrepancies 0.01442887 R value 40.31946516
# Iter 55 Primal Discrepancies 0.01192319 R value 40.31290100
# Iter 56 Primal Discrepancies 0.01171387 R value 40.30701530
# Iter 57 Primal Discrepancies 0.01224577 R value 40.30190843
# Iter 58 Primal Discrepancies 0.01193597 R value 40.29753523
# Iter 59 Primal Discrepancies 0.01072572 R value 40.29375569
# Iter 60 Primal Discrepancies 0.00915459 R value 40.29040151
# Iter 61 Primal Discrepancies 0.00803584 R value 40.28733075
# Iter 62 Primal Discrepancies 0.00781116 R value 40.28445633
# Iter 63 Primal Discrepancies 0.00761360 R value 40.28174752
# Iter 64 Primal Discrepancies 0.00717416 R value 40.27921296
# Iter 65 Primal Discrepancies 0.00661432 R value 40.27687695
# Iter 66 Primal Discrepancies 0.00627169 R value 40.27475911
# Iter 67 Primal Discrepancies 0.00601104 R value 40.27286312
# Iter 68 Primal Discrepancies 0.00570457 R value 40.27117501
# Iter 69 Primal Discrepancies 0.00537335 R value 40.26966850
# Iter 70 Primal Discrepancies 0.00510515 R value 40.26831313
# Iter 71 Primal Discrepancies 0.00485455 R value 40.26708144
# Iter 72 Primal Discrepancies 0.00461990 R value 40.26595322
# Iter 73 Primal Discrepancies 0.00439868 R value 40.26491621
# Iter 74 Primal Discrepancies 0.00418847 R value 40.26396430
# Iter 75 Primal Discrepancies 0.00398749 R value 40.26309450
# Iter 76 Primal Discrepancies 0.00379484 R value 40.26230426
# Iter 77 Primal Discrepancies 0.00361031 R value 40.26158967
# Iter 78 Primal Discrepancies 0.00343412 R value 40.26094501
# Iter 79 Primal Discrepancies 0.00326650 R value 40.26036324
# Iter 80 Primal Discrepancies 0.00310751 R value 40.25983692
# Iter 81 Primal Discrepancies 0.00295692 R value 40.25935921
# Iter 82 Primal Discrepancies 0.00281425 R value 40.25892436
# Iter 83 Primal Discrepancies 0.00267889 R value 40.25852793
# Iter 84 Primal Discrepancies 0.00255024 R value 40.25816657
# Iter 85 Primal Discrepancies 0.00242777 R value 40.25783763
# Iter 86 Primal Discrepancies 0.00231109 R value 40.25753876
# Iter 87 Primal Discrepancies 0.00219992 R value 40.25726769
# Iter 88 Primal Discrepancies 0.00209406 R value 40.25702208
# Iter 89 Primal Discrepancies 0.00199332 R value 40.25679953
# Iter 90 Primal Discrepancies 0.00189753 R value 40.25659775
# Iter 91 Primal Discrepancies 0.00180647 R value 40.25641460
# Iter 92 Primal Discrepancies 0.00171991 R value 40.25624818
# Iter 93 Primal Discrepancies 0.00163761 R value 40.25609688
# Iter 94 Primal Discrepancies 0.00155931 R value 40.25595931
# Iter 95 Primal Discrepancies 0.00148479 R value 40.25583427
# Iter 96 Primal Discrepancies 0.00141386 R value 40.25572069
# Iter 97 Primal Discrepancies 0.00134633 R value 40.25561759
# Iter 98 Primal Discrepancies 0.00128205 R value 40.25552404
# Iter 99 Primal Discrepancies 0.00122086 R value 40.25543915
# Iter 100 Primal Discrepancies 0.00116262 R value 40.25536212
# Iter 101 Primal Discrepancies 0.00110720 R value 40.25529219
# Iter 102 Primal Discrepancies 0.00105446 R value 40.25522868
# Iter 103 Primal Discrepancies 0.00100425 R value 40.25517098
# Iter 104 Primal Discrepancies 0.00095647 R value 40.25511857
# Iter 105 Primal Discrepancies 0.00091098 R value 40.25507097
# Iter 106 Primal Discrepancies 0.00086767 R value 40.25502773
# Iter 107 Primal Discrepancies 0.00082643 R value 40.25498848
# Iter 108 Primal Discrepancies 0.00078716 R value 40.25495284
# Iter 109 Primal Discrepancies 0.00074977 R value 40.25492049
# Iter 110 Primal Discrepancies 0.00071417 R value 40.25489112
# Iter 111 Primal Discrepancies 0.00068028 R value 40.25486446
# Iter 112 Primal Discrepancies 0.00064800 R value 40.25484024
# Iter 113 Primal Discrepancies 0.00061727 R value 40.25481825
# Iter 114 Primal Discrepancies 0.00058800 R value 40.25479829
# Iter 115 Primal Discrepancies 0.00056013 R value 40.25478015
# Iter 116 Primal Discrepancies 0.00053359 R value 40.25476368
# Iter 117 Primal Discrepancies 0.00050831 R value 40.25474873
# Iter 118 Primal Discrepancies 0.00048424 R value 40.25473516
# Iter 119 Primal Discrepancies 0.00046131 R value 40.25472283
# Iter 120 Primal Discrepancies 0.00043947 R value 40.25471164
# Iter 121 Primal Discrepancies 0.00041867 R value 40.25470148
# Iter 122 Primal Discrepancies 0.00039886 R value 40.25469225
# Iter 123 Primal Discrepancies 0.00037999 R value 40.25468387
# Iter 124 Primal Discrepancies 0.00036202 R value 40.25467626
# Iter 125 Primal Discrepancies 0.00034490 R value 40.25466935
# Iter 126 Primal Discrepancies 0.00032859 R value 40.25466308
# Iter 127 Primal Discrepancies 0.00031306 R value 40.25465738
# Iter 128 Primal Discrepancies 0.00029826 R value 40.25465221
# Iter 129 Primal Discrepancies 0.00028416 R value 40.25464751
# Iter 130 Primal Discrepancies 0.00027074 R value 40.25464325
# Iter 131 Primal Discrepancies 0.00025795 R value 40.25463938
# Iter 132 Primal Discrepancies 0.00024576 R value 40.25463586
# Iter 133 Primal Discrepancies 0.00023415 R value 40.25463267
# Iter 134 Primal Discrepancies 0.00022310 R value 40.25462977
# Iter 135 Primal Discrepancies 0.00021256 R value 40.25462714
# Iter 136 Primal Discrepancies 0.00020253 R value 40.25462475
# Iter 137 Primal Discrepancies 0.00019296 R value 40.25462258
# Iter 138 Primal Discrepancies 0.00018386 R value 40.25462061
# Iter 139 Primal Discrepancies 0.00017518 R value 40.25461882
# Iter 140 Primal Discrepancies 0.00016691 R value 40.25461720
# Iter 141 Primal Discrepancies 0.00015903 R value 40.25461572
# Iter 142 Primal Discrepancies 0.00015153 R value 40.25461438
# Iter 143 Primal Discrepancies 0.00014438 R value 40.25461316
# Iter 144 Primal Discrepancies 0.00013757 R value 40.25461206
# Iter 145 Primal Discrepancies 0.00013108 R value 40.25461106
# Iter 146 Primal Discrepancies 0.00012490 R value 40.25461015
# Iter 147 Primal Discrepancies 0.00011900 R value 40.25460932
# Iter 148 Primal Discrepancies 0.00011339 R value 40.25460857
# Iter 149 Primal Discrepancies 0.00010804 R value 40.25460789
# Iter 150 Primal Discrepancies 0.00010295 R value 40.25460727
# Iter 151 Primal Discrepancies 0.00009809 R value 40.25460671
# Iter 152 Primal Discrepancies 0.00009347 R value 40.25460620
# Iter 153 Primal Discrepancies 0.00008906 R value 40.25460573
# Iter 154 Primal Discrepancies 0.00008486 R value 40.25460531
# Iter 155 Primal Discrepancies 0.00008086 R value 40.25460493
# Iter 156 Primal Discrepancies 0.00007705 R value 40.25460458
# Iter 157 Primal Discrepancies 0.00007342 R value 40.25460427
# Iter 158 Primal Discrepancies 0.00006995 R value 40.25460398
# Iter 159 Primal Discrepancies 0.00006666 R value 40.25460372
# Iter 160 Primal Discrepancies 0.00006351 R value 40.25460349
# Iter 161 Primal Discrepancies 0.00006052 R value 40.25460327
# Iter 162 Primal Discrepancies 0.00005767 R value 40.25460308
# Iter 163 Primal Discrepancies 0.00005495 R value 40.25460290
# Iter 164 Primal Discrepancies 0.00005236 R value 40.25460274
# Iter 165 Primal Discrepancies 0.00004989 R value 40.25460260
# Iter 166 Primal Discrepancies 0.00004754 R value 40.25460246
# Iter 167 Primal Discrepancies 0.00004530 R value 40.25460234
# Iter 168 Primal Discrepancies 0.00004317 R value 40.25460223
# Iter 169 Primal Discrepancies 0.00004113 R value 40.25460214
# Iter 170 Primal Discrepancies 0.00003919 R value 40.25460205
# Iter 171 Primal Discrepancies 0.00003735 R value 40.25460196
# Iter 172 Primal Discrepancies 0.00003559 R value 40.25460189
# Iter 173 Primal Discrepancies 0.00003391 R value 40.25460182
# Iter 174 Primal Discrepancies 0.00003231 R value 40.25460176
# Iter 175 Primal Discrepancies 0.00003079 R value 40.25460171
# Iter 176 Primal Discrepancies 0.00002934 R value 40.25460166
# Iter 177 Primal Discrepancies 0.00002796 R value 40.25460161
# Iter 178 Primal Discrepancies 0.00002664 R value 40.25460157
# Iter 179 Primal Discrepancies 0.00002538 R value 40.25460153
# Iter 180 Primal Discrepancies 0.00002419 R value 40.25460150
# Iter 181 Primal Discrepancies 0.00002305 R value 40.25460147
# Iter 182 Primal Discrepancies 0.00002196 R value 40.25460144
# Iter 183 Primal Discrepancies 0.00002093 R value 40.25460141
# Iter 184 Primal Discrepancies 0.00001994 R value 40.25460139
# Iter 185 Primal Discrepancies 0.00001900 R value 40.25460137
# Iter 186 Primal Discrepancies 0.00001811 R value 40.25460135
# Iter 187 Primal Discrepancies 0.00001725 R value 40.25460133
# Iter 188 Primal Discrepancies 0.00001644 R value 40.25460131
# Iter 189 Primal Discrepancies 0.00001567 R value 40.25460130
# Iter 190 Primal Discrepancies 0.00001493 R value 40.25460129
# Iter 191 Primal Discrepancies 0.00001422 R value 40.25460128
# Iter 192 Primal Discrepancies 0.00001355 R value 40.25460126
# Iter 193 Primal Discrepancies 0.00001292 R value 40.25460125
# Iter 194 Primal Discrepancies 0.00001231 R value 40.25460125
# Iter 195 Primal Discrepancies 0.00001173 R value 40.25460124
# Iter 196 Primal Discrepancies 0.00001118 R value 40.25460123
# Iter 197 Primal Discrepancies 0.00001065 R value 40.25460122
# Iter 198 Primal Discrepancies 0.00001015 R value 40.25460122
# Iter 199 Primal Discrepancies 0.00000967 R value 40.25460121
# Iter 200 Primal Discrepancies 0.00000921 R value 40.25460121
# Iter 201 Primal Discrepancies 0.00000878 R value 40.25460120
# Iter 202 Primal Discrepancies 0.00000837 R value 40.25460120
# Iter 203 Primal Discrepancies 0.00000797 R value 40.25460120
# Iter 204 Primal Discrepancies 0.00000760 R value 40.25460119
# Iter 205 Primal Discrepancies 0.00000724 R value 40.25460119
# Iter 206 Primal Discrepancies 0.00000690 R value 40.25460119
# Iter 207 Primal Discrepancies 0.00000657 R value 40.25460118
# Iter 208 Primal Discrepancies 0.00000626 R value 40.25460118
# Iter 209 Primal Discrepancies 0.00000597 R value 40.25460118
# Iter 210 Primal Discrepancies 0.00000569 R value 40.25460118
# Iter 211 Primal Discrepancies 0.00000542 R value 40.25460118
# Iter 212 Primal Discrepancies 0.00000516 R value 40.25460117
# Iter 213 Primal Discrepancies 0.00000492 R value 40.25460117
# Iter 214 Primal Discrepancies 0.00000469 R value 40.25460117
# Iter 215 Primal Discrepancies 0.00000447 R value 40.25460117
# Iter 216 Primal Discrepancies 0.00000426 R value 40.25460117
# Iter 217 Primal Discrepancies 0.00000406 R value 40.25460117
# Iter 218 Primal Discrepancies 0.00000387 R value 40.25460117
# Iter 219 Primal Discrepancies 0.00000368 R value 40.25460117
# Iter 220 Primal Discrepancies 0.00000351 R value 40.25460117
# Iter 221 Primal Discrepancies 0.00000334 R value 40.25460116
# Iter 222 Primal Discrepancies 0.00000319 R value 40.25460116
# Iter 223 Primal Discrepancies 0.00000304 R value 40.25460116
# Iter 224 Primal Discrepancies 0.00000289 R value 40.25460116
# Iter 225 Primal Discrepancies 0.00000276 R value 40.25460116
# Iter 226 Primal Discrepancies 0.00000263 R value 40.25460116
# Iter 227 Primal Discrepancies 0.00000250 R value 40.25460116
# Iter 228 Primal Discrepancies 0.00000239 R value 40.25460116
# Iter 229 Primal Discrepancies 0.00000227 R value 40.25460116
# Iter 230 Primal Discrepancies 0.00000217 R value 40.25460116
# Iter 231 Primal Discrepancies 0.00000206 R value 40.25460116
# Iter 232 Primal Discrepancies 0.00000197 R value 40.25460116
# Iter 233 Primal Discrepancies 0.00000187 R value 40.25460116
# Iter 234 Primal Discrepancies 0.00000179 R value 40.25460116
# Iter 235 Primal Discrepancies 0.00000170 R value 40.25460116
# Iter 236 Primal Discrepancies 0.00000162 R value 40.25460116
# Iter 237 Primal Discrepancies 0.00000155 R value 40.25460116
# Iter 238 Primal Discrepancies 0.00000147 R value 40.25460116
# Iter 239 Primal Discrepancies 0.00000140 R value 40.25460116
# Iter 240 Primal Discrepancies 0.00000134 R value 40.25460116
# Iter 241 Primal Discrepancies 0.00000127 R value 40.25460116
# Iter 242 Primal Discrepancies 0.00000121 R value 40.25460116
# Iter 243 Primal Discrepancies 0.00000116 R value 40.25460116
# Iter 244 Primal Discrepancies 0.00000110 R value 40.25460116
# Iter 245 Primal Discrepancies 0.00000105 R value 40.25460116
# Iter 246 Primal Discrepancies 0.00000100 R value 40.25460116
# Iter 247 Primal Discrepancies 0.00000095 R value 40.25460116
# Iter 248 Primal Discrepancies 0.00000091 R value 40.25460116
# Iter 249 Primal Discrepancies 0.00000087 R value 40.25460116
# Iter 250 Primal Discrepancies 0.00000083 R value 40.25460116
# Iter 251 Primal Discrepancies 0.00000079 R value 40.25460116
# Iter 252 Primal Discrepancies 0.00000075 R value 40.25460116
# Iter 253 Primal Discrepancies 0.00000071 R value 40.25460116
# Iter 254 Primal Discrepancies 0.00000068 R value 40.25460116
# Iter 255 Primal Discrepancies 0.00000065 R value 40.25460116
# Iter 256 Primal Discrepancies 0.00000062 R value 40.25460116
# Iter 257 Primal Discrepancies 0.00000059 R value 40.25460116
# Iter 258 Primal Discrepancies 0.00000056 R value 40.25460116
# Iter 259 Primal Discrepancies 0.00000053 R value 40.25460116
# Iter 260 Primal Discrepancies 0.00000051 R value 40.25460116
# Iter 261 Primal Discrepancies 0.00000049 R value 40.25460116
# Iter 262 Primal Discrepancies 0.00000046 R value 40.25460116
# Iter 263 Primal Discrepancies 0.00000044 R value 40.25460116
# Iter 264 Primal Discrepancies 0.00000042 R value 40.25460116
# Iter 265 Primal Discrepancies 0.00000040 R value 40.25460116
# Iter 266 Primal Discrepancies 0.00000038 R value 40.25460116
# Iter 267 Primal Discrepancies 0.00000036 R value 40.25460116
# Iter 268 Primal Discrepancies 0.00000035 R value 40.25460116
# Iter 269 Primal Discrepancies 0.00000033 R value 40.25460116
# Iter 270 Primal Discrepancies 0.00000031 R value 40.25460116
# Iter 271 Primal Discrepancies 0.00000030 R value 40.25460116
# Iter 272 Primal Discrepancies 0.00000029 R value 40.25460116
# Iter 273 Primal Discrepancies 0.00000027 R value 40.25460116
# Iter 274 Primal Discrepancies 0.00000026 R value 40.25460116
# Iter 275 Primal Discrepancies 0.00000025 R value 40.25460116
# Iter 276 Primal Discrepancies 0.00000024 R value 40.25460116
# Iter 277 Primal Discrepancies 0.00000022 R value 40.25460116
# Iter 278 Primal Discrepancies 0.00000021 R value 40.25460116
# Iter 279 Primal Discrepancies 0.00000020 R value 40.25460116
# Iter 280 Primal Discrepancies 0.00000019 R value 40.25460116
# Iter 281 Primal Discrepancies 0.00000018 R value 40.25460116
# Iter 282 Primal Discrepancies 0.00000018 R value 40.25460116
# Iter 283 Primal Discrepancies 0.00000017 R value 40.25460116
# Iter 284 Primal Discrepancies 0.00000016 R value 40.25460116
# Iter 285 Primal Discrepancies 0.00000015 R value 40.25460116
# Iter 286 Primal Discrepancies 0.00000015 R value 40.25460116
# Iter 287 Primal Discrepancies 0.00000014 R value 40.25460116
# Iter 288 Primal Discrepancies 0.00000013 R value 40.25460116
# Iter 289 Primal Discrepancies 0.00000013 R value 40.25460116
# Iter 290 Primal Discrepancies 0.00000012 R value 40.25460116
# Iter 291 Primal Discrepancies 0.00000011 R value 40.25460116
# Iter 292 Primal Discrepancies 0.00000011 R value 40.25460116
# Iter 293 Primal Discrepancies 0.00000010 R value 40.25460116
# Iter 294 Primal Discrepancies 0.00000010 R value 40.25460116
# Iter 295 Primal Discrepancies 0.00000009 R value 40.25460116
# Iter 296 Primal Discrepancies 0.00000009 R value 40.25460116
# Iter 297 Primal Discrepancies 0.00000009 R value 40.25460116
# Iter 298 Primal Discrepancies 0.00000008 R value 40.25460116
# Iter 299 Primal Discrepancies 0.00000008 R value 40.25460116
# Iter 300 Primal Discrepancies 0.00000007 R value 40.25460116
# Iter 301 Primal Discrepancies 0.00000007 R value 40.25460116
# Iter 302 Primal Discrepancies 0.00000007 R value 40.25460116
# Iter 303 Primal Discrepancies 0.00000006 R value 40.25460116
# Iter 304 Primal Discrepancies 0.00000006 R value 40.25460116
# Iter 305 Primal Discrepancies 0.00000006 R value 40.25460116
# Iter 306 Primal Discrepancies 0.00000006 R value 40.25460116
# Iter 307 Primal Discrepancies 0.00000005 R value 40.25460116
# Iter 308 Primal Discrepancies 0.00000005 R value 40.25460116
# Iter 309 Primal Discrepancies 0.00000005 R value 40.25460116
# Iter 310 Primal Discrepancies 0.00000005 R value 40.25460116
# Iter 311 Primal Discrepancies 0.00000004 R value 40.25460116
# Iter 312 Primal Discrepancies 0.00000004 R value 40.25460116
# Iter 313 Primal Discrepancies 0.00000004 R value 40.25460116
# Iter 314 Primal Discrepancies 0.00000004 R value 40.25460116
# Iter 315 Primal Discrepancies 0.00000004 R value 40.25460116
# Iter 316 Primal Discrepancies 0.00000003 R value 40.25460116
# Iter 317 Primal Discrepancies 0.00000003 R value 40.25460116
# Iter 318 Primal Discrepancies 0.00000003 R value 40.25460116
# Iter 319 Primal Discrepancies 0.00000003 R value 40.25460116
# Iter 320 Primal Discrepancies 0.00000003 R value 40.25460116
# Iter 321 Primal Discrepancies 0.00000003 R value 40.25460116
# Iter 322 Primal Discrepancies 0.00000003 R value 40.25460116
# Iter 323 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 324 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 325 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 326 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 327 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 328 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 329 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 330 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 331 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 332 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 333 Primal Discrepancies 0.00000002 R value 40.25460116
# Iter 334 Primal Discrepancies 0.00000001 R value 40.25460116
# Iter 335 Primal Discrepancies 0.00000001 R value 40.25460116
# Iter 336 Primal Discrepancies 0.00000001 R value 40.25460116
# Iter 337 Primal Discrepancies 0.00000001 R value 40.25460116
# Iter 338 Primal Discrepancies 0.00000001 R value 40.25460116
# Iter 339 Primal Discrepancies 0.00000001 R value 40.25460116
# Iter 340 Primal Discrepancies 0.00000001 R value 40.25460116
# Iter 341 Primal Discrepancies 0.00000001 R value 40.25460116
# Iter 342 Primal Discrepancies 0.00000001 R value 40.25460116
# Iter 343 Primal Discrepancies 0.00000001 R value 40.25460116
# Iter 344 Primal Discrepancies 0.00000001 R value 40.25460116
# Stopping at iteration 344
# X = 30.920146220602106
# Y = 36.54579318469892
# R = 40.254601158361574
# Correct values are:
# X = 30.920145668409557
# Y = 36.54579442364673
# R = 40.254601163366

# %%
##QP_ADMM for 4 selected circles in n=20, m=50 test case

using JuMP
using Printf
import Juniper
import Ipopt

a = [8.952575686584531, 46.74153578924209, 32.34771758225827, 11.355837839937607] # x-cordinates of selected circle
b = [38.87977889206978, 23.45904720270292, 37.565559688461505, 13.734380115583644] # y-cordinates of selected circle
r = [20, 20, 20, 20 ] # Radius of selected circles
   
   

NumVar = size(r)[1] 

rho = 1.0  ### Augmented Lagrangian penalty coefficient
  ## Note: rho may be allowed to vary under restriction


## Typing of parameters is optional, but wise.
## Form the AL primal subproblem
function solveSP(i::Int64, vdual::Dict{String,Float64}, X::Float64,Y::Float64, R::Float64 )

  model = Model(
        optimizer_with_attributes(
            #Juniper.Optimizer,
            #"nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
            #    MOI.Silent() => true,
            #),
        ),
    )
    set_optimizer_attribute(model, "print_level", 0)  ### Suppress Ipopt output
    set_optimizer_attribute(model, "tol", 1e-14)  ### Not required in general

    @variable(model, x )
    @variable(model, y )
    @variable(model, z >= 0)
  
    ### primal objective + Lagrange terms + augmented (squared penalty) terms
    @objective(model, Min, z+r[i] 
	+ vdual["x"]*(x + X - a[i]) + vdual["y"]*(y + Y - b[i]) + vdual["z"]*(z + r[i] - R)
	+ 0.5*rho*( (x+X-a[i])^2 + (y+Y-b[i])^2 + (z+r[i]-R)^2 ) )

    ### All coupling constraints are relaxed.
    @constraint( model, xyz, x^2 + y^2 <= z^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
  ## Initialization
    x = Dict{Int64,Float64}()
    y = Dict{Int64,Float64}()
    z = Dict{Int64,Float64}()

    ### Initialize Lagrangian multipliers to zero value
    vdual = Dict{Int64, Dict{String,Float64}}()
    for i in 1:NumVar
	vdual[i] = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    end

    X,Y,R=0.0,0.0,0.0
    oldX,oldY,oldR=0.0,0.0,0.0
    ### Initialize R to average of r[i], i=1,...,n
    for i in 1:length(a)
	R += (1.0/NumVar)*(r[i])
    end
  ## End of initialization

for n in 1:1000
    ### Solve AL subproblem for each subproblem i with X,Y,R fixed
    for i in 1:NumVar
      x[i],y[i],z[i] = solveSP(i,vdual[i],X,Y,R)
    end

    ### Subproblems in X,Y,R (with x,y,z fixed) can be solved in closed-form
    oldX,oldY,oldR=X,Y,R
    X,Y,R=0.0,0.0,0.0
    for i in 1:NumVar
	X += (1.0/NumVar)*(a[i]-x[i])
	Y += (1.0/NumVar)*(b[i]-y[i])
	R += (1.0/NumVar)*(z[i]+r[i])
    end

    ### Update Lagrange multipliers, compute a measure of primal infeasibility.
    discr = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    for i in 1:NumVar
	vdual[i]["x"] += rho*(x[i] + X - a[i]) 
	vdual[i]["y"] += rho*(y[i] + Y - b[i]) 
	vdual[i]["z"] += rho*(z[i] + r[i] - R)

	discr["x"] += abs(x[i] + X - a[i])
	discr["y"] += abs(y[i] + Y - b[i])
	discr["z"] += abs(z[i] + r[i] - R)
    end
    @printf("Iter %d Primal Discrepancies %8.8f R value %8.8f\n", 
	n, discr["x"] + discr["y"] + discr["z"], R)
    d_discr = abs(X-oldX)+abs(Y-oldY)+abs(R-oldR) ### Dual residues
    if discr["x"] + discr["y"] + discr["z"] + d_discr < 1e-7
	println("Stopping at iteration ",n)  ### Primal feasible within tolerance
	break
    end
end
    @show(X)
    @show(Y)
    @show(R)

println("Correct values are: ")

println("X = ",26.50038624217553)
println("Y = ",27.86935953170211)
println("R = ",40.71605633426372)
end

main()
# Out:
# Iter 1 Primal Discrepancies 71.69202420 R value 39.44875059
# Iter 2 Primal Discrepancies 19.18066262 R value 47.11887062
# Iter 3 Primal Discrepancies 36.16155969 R value 49.43045484
# Iter 4 Primal Discrepancies 15.77218649 R value 50.03878864
# Iter 5 Primal Discrepancies 12.45279713 R value 49.65665032
# Iter 6 Primal Discrepancies 7.92289313 R value 48.65665032
# Iter 7 Primal Discrepancies 0.00000000 R value 47.65665032
# Iter 8 Primal Discrepancies 0.00000000 R value 46.65665032
# Iter 9 Primal Discrepancies 0.00000000 R value 45.65665032
# Iter 10 Primal Discrepancies 0.00000000 R value 44.65665032
# Iter 11 Primal Discrepancies 0.39449678 R value 43.69168687
# Iter 12 Primal Discrepancies 2.58148694 R value 42.98961309
# Iter 13 Primal Discrepancies 3.30089947 R value 42.62360858
# Iter 14 Primal Discrepancies 2.78400462 R value 42.54069117
# Iter 15 Primal Discrepancies 1.61277370 R value 42.62152357
# Iter 16 Primal Discrepancies 0.39755024 R value 42.73949463
# Iter 17 Primal Discrepancies 0.56772927 R value 42.80057033
# Iter 18 Primal Discrepancies 1.00556155 R value 42.75958160
# Iter 19 Primal Discrepancies 0.99949605 R value 42.61716724
# Iter 20 Primal Discrepancies 0.68860494 R value 42.40497625
# Iter 21 Primal Discrepancies 0.26196005 R value 42.16699511
# Iter 22 Primal Discrepancies 0.16034822 R value 41.94330591
# Iter 23 Primal Discrepancies 0.40143666 R value 41.75998865
# Iter 24 Primal Discrepancies 0.48364000 R value 41.62605682
# Iter 25 Primal Discrepancies 0.42838709 R value 41.53607102
# Iter 26 Primal Discrepancies 0.29544365 R value 41.47591497
# Iter 27 Primal Discrepancies 0.16005151 R value 41.42915632
# Iter 28 Primal Discrepancies 0.07403679 R value 41.38209461
# Iter 29 Primal Discrepancies 0.10999299 R value 41.32656121
# Iter 30 Primal Discrepancies 0.12702375 R value 41.26042145
# Iter 31 Primal Discrepancies 0.10237474 R value 41.18633878
# Iter 32 Primal Discrepancies 0.06190736 R value 41.10963740
# Iter 33 Primal Discrepancies 0.07078883 R value 41.03608209
# Iter 34 Primal Discrepancies 0.10129769 R value 40.97017466
# Iter 35 Primal Discrepancies 0.12116128 R value 40.91425992
# Iter 36 Primal Discrepancies 0.12157128 R value 40.86844209
# Iter 37 Primal Discrepancies 0.10671194 R value 40.83110502
# Iter 38 Primal Discrepancies 0.08493570 R value 40.79973404
# Iter 39 Primal Discrepancies 0.06610115 R value 40.77174605
# Iter 40 Primal Discrepancies 0.05063660 R value 40.74511417
# Iter 41 Primal Discrepancies 0.04241903 R value 40.71868451
# Iter 42 Primal Discrepancies 0.25685192 R value 40.71121261
# Iter 43 Primal Discrepancies 0.44254540 R value 40.72634411
# Iter 44 Primal Discrepancies 0.52895336 R value 40.75426402
# Iter 45 Primal Discrepancies 0.59205123 R value 40.78125536
# Iter 46 Primal Discrepancies 0.62091456 R value 40.79712412
# Iter 47 Primal Discrepancies 0.59181009 R value 40.79823961
# Iter 48 Primal Discrepancies 0.51385215 R value 40.78671977
# Iter 49 Primal Discrepancies 0.40071315 R value 40.76767678
# Iter 50 Primal Discrepancies 0.26763722 R value 40.74643213
# Iter 51 Primal Discrepancies 0.13242062 R value 40.72681298
# Iter 52 Primal Discrepancies 0.03397005 R value 40.71072483
# Iter 53 Primal Discrepancies 0.11639827 R value 40.69859484
# Iter 54 Primal Discrepancies 0.20642951 R value 40.69010843
# Iter 55 Primal Discrepancies 0.26797132 R value 40.68480427
# Iter 56 Primal Discrepancies 0.29955434 R value 40.68235118
# Iter 57 Primal Discrepancies 0.30233455 R value 40.68254772
# Iter 58 Primal Discrepancies 0.27972889 R value 40.68518784
# Iter 59 Primal Discrepancies 0.23686960 R value 40.68993185
# Iter 60 Primal Discrepancies 0.17993736 R value 40.69625898
# Iter 61 Primal Discrepancies 0.11546826 R value 40.70350813
# Iter 62 Primal Discrepancies 0.04978963 R value 40.71097048
# Iter 63 Primal Discrepancies 0.01474372 R value 40.71798752
# Iter 64 Primal Discrepancies 0.06463090 R value 40.72402296
# Iter 65 Primal Discrepancies 0.10569113 R value 40.72869801
# Iter 66 Primal Discrepancies 0.13313088 R value 40.73179679
# Iter 67 Primal Discrepancies 0.14640065 R value 40.73325459
# Iter 68 Primal Discrepancies 0.14611278 R value 40.73313985
# Iter 69 Primal Discrepancies 0.13387163 R value 40.73163460
# Iter 70 Primal Discrepancies 0.11205694 R value 40.72901278
# Iter 71 Primal Discrepancies 0.08356857 R value 40.72561414
# Iter 72 Primal Discrepancies 0.05154640 R value 40.72181273
# Iter 73 Primal Discrepancies 0.01908598 R value 40.71798138
# Iter 74 Primal Discrepancies 0.01123491 R value 40.71445657
# Iter 75 Primal Discrepancies 0.03651794 R value 40.71150885
# Iter 76 Primal Discrepancies 0.05579713 R value 40.70932296
# Iter 77 Primal Discrepancies 0.06799889 R value 40.70799015
# Iter 78 Primal Discrepancies 0.07298235 R value 40.70751206
# Iter 79 Primal Discrepancies 0.07124731 R value 40.70781407
# Iter 80 Primal Discrepancies 0.06380284 R value 40.70876439
# Iter 81 Primal Discrepancies 0.05200761 R value 40.71019542
# Iter 82 Primal Discrepancies 0.03740326 R value 40.71192417
# Iter 83 Primal Discrepancies 0.02155811 R value 40.71376993
# Iter 84 Primal Discrepancies 0.00631300 R value 40.71556818
# Iter 85 Primal Discrepancies 0.00821910 R value 40.71718061
# Iter 86 Primal Discrepancies 0.01993045 R value 40.71850155
# Iter 87 Primal Discrepancies 0.02855115 R value 40.71946127
# Iter 88 Primal Discrepancies 0.03376187 R value 40.72002666
# Iter 89 Primal Discrepancies 0.03555702 R value 40.72019937
# Iter 90 Primal Discrepancies 0.03420722 R value 40.72001200
# Iter 91 Primal Discrepancies 0.03020540 R value 40.71952230
# Iter 92 Primal Discrepancies 0.02420185 R value 40.71880610
# Iter 93 Primal Discrepancies 0.01693373 R value 40.71794930
# Iter 94 Primal Discrepancies 0.00915501 R value 40.71703973
# Iter 95 Primal Discrepancies 0.00206981 R value 40.71615953
# Iter 96 Primal Discrepancies 0.00520861 R value 40.71537873
# Iter 97 Primal Discrepancies 0.01072190 R value 40.71475062
# Iter 98 Primal Discrepancies 0.01466447 R value 40.71430904
# Iter 99 Primal Discrepancies 0.01690199 R value 40.71406787
# Iter 100 Primal Discrepancies 0.01745963 R value 40.71402225
# Iter 101 Primal Discrepancies 0.01650001 R value 40.71415143
# Iter 102 Primal Discrepancies 0.01429220 R value 40.71442263
# Iter 103 Primal Discrepancies 0.01117544 R value 40.71479537
# Iter 104 Primal Discrepancies 0.00752177 R value 40.71522592
# Iter 105 Primal Discrepancies 0.00370075 R value 40.71567138
# Iter 106 Primal Discrepancies 0.00056384 R value 40.71609309
# Iter 107 Primal Discrepancies 0.00315256 R value 40.71645928
# Iter 108 Primal Discrepancies 0.00569633 R value 40.71674675
# Iter 109 Primal Discrepancies 0.00745417 R value 40.71694164
# Iter 110 Primal Discrepancies 0.00837867 R value 40.71703940
# Iter 111 Primal Discrepancies 0.00849683 R value 40.71704400
# Iter 112 Primal Discrepancies 0.00789859 R value 40.71696655
# Iter 113 Primal Discrepancies 0.00672180 R value 40.71682352
# Iter 114 Primal Discrepancies 0.00513497 R value 40.71663477
# Iter 115 Primal Discrepancies 0.00331975 R value 40.71642152
# Iter 116 Primal Discrepancies 0.00145436 R value 40.71620441
# Iter 117 Primal Discrepancies 0.00038809 R value 40.71600186
# Iter 118 Primal Discrepancies 0.00181397 R value 40.71582886
# Iter 119 Primal Discrepancies 0.00298992 R value 40.71569608
# Iter 120 Primal Discrepancies 0.00377293 R value 40.71560957
# Iter 121 Primal Discrepancies 0.00414679 R value 40.71557075
# Iter 122 Primal Discrepancies 0.00413121 R value 40.71557694
# Iter 123 Primal Discrepancies 0.00377573 R value 40.71562204
# Iter 124 Primal Discrepancies 0.00315192 R value 40.71569749
# Iter 125 Primal Discrepancies 0.00234470 R value 40.71579328
# Iter 126 Primal Discrepancies 0.00144360 R value 40.71589894
# Iter 127 Primal Discrepancies 0.00053498 R value 40.71600453
# Iter 128 Primal Discrepancies 0.00031255 R value 40.71610131
# Iter 129 Primal Discrepancies 0.00101655 R value 40.71618238
# Iter 130 Primal Discrepancies 0.00155538 R value 40.71624299
# Iter 131 Primal Discrepancies 0.00189887 R value 40.71628066
# Iter 132 Primal Discrepancies 0.00204283 R value 40.71629512
# Iter 133 Primal Discrepancies 0.00200006 R value 40.71628805
# Iter 134 Primal Discrepancies 0.00179721 R value 40.71626270
# Iter 135 Primal Discrepancies 0.00147088 R value 40.71622342
# Iter 136 Primal Discrepancies 0.00106331 R value 40.71617519
# Iter 137 Primal Discrepancies 0.00061828 R value 40.71612310
# Iter 138 Primal Discrepancies 0.00018428 R value 40.71607193
# Iter 139 Primal Discrepancies 0.00022392 R value 40.71602581
# Iter 140 Primal Discrepancies 0.00055685 R value 40.71598793
# Iter 141 Primal Discrepancies 0.00080251 R value 40.71596040
# Iter 142 Primal Discrepancies 0.00095136 R value 40.71594421
# Iter 143 Primal Discrepancies 0.00100310 R value 40.71593930
# Iter 144 Primal Discrepancies 0.00096547 R value 40.71594467
# Iter 145 Primal Discrepancies 0.00085264 R value 40.71595862
# Iter 146 Primal Discrepancies 0.00068328 R value 40.71597892
# Iter 147 Primal Discrepancies 0.00047839 R value 40.71600310
# Iter 148 Primal Discrepancies 0.00025931 R value 40.71602870
# Iter 149 Primal Discrepancies 0.00006038 R value 40.71605340
# Iter 150 Primal Discrepancies 0.00014482 R value 40.71607529
# Iter 151 Primal Discrepancies 0.00029997 R value 40.71609290
# Iter 152 Primal Discrepancies 0.00041110 R value 40.71610530
# Iter 153 Primal Discrepancies 0.00047447 R value 40.71611212
# Iter 154 Primal Discrepancies 0.00049076 R value 40.71611348
# Iter 155 Primal Discrepancies 0.00046445 R value 40.71610995
# Iter 156 Primal Discrepancies 0.00040299 R value 40.71610242
# Iter 157 Primal Discrepancies 0.00031581 R value 40.71609201
# Iter 158 Primal Discrepancies 0.00021331 R value 40.71607994
# Iter 159 Primal Discrepancies 0.00010586 R value 40.71606741
# Iter 160 Primal Discrepancies 0.00001641 R value 40.71605551
# Iter 161 Primal Discrepancies 0.00008743 R value 40.71604516
# Iter 162 Primal Discrepancies 0.00015940 R value 40.71603701
# Iter 163 Primal Discrepancies 0.00020928 R value 40.71603147
# Iter 164 Primal Discrepancies 0.00023567 R value 40.71602867
# Iter 165 Primal Discrepancies 0.00023931 R value 40.71602850
# Iter 166 Primal Discrepancies 0.00022270 R value 40.71603066
# Iter 167 Primal Discrepancies 0.00018973 R value 40.71603467
# Iter 168 Primal Discrepancies 0.00014515 R value 40.71603998
# Iter 169 Primal Discrepancies 0.00009410 R value 40.71604598
# Iter 170 Primal Discrepancies 0.00004158 R value 40.71605209
# Iter 171 Primal Discrepancies 0.00001051 R value 40.71605780
# Iter 172 Primal Discrepancies 0.00005055 R value 40.71606268
# Iter 173 Primal Discrepancies 0.00008376 R value 40.71606642
# Iter 174 Primal Discrepancies 0.00010593 R value 40.71606887
# Iter 175 Primal Discrepancies 0.00011659 R value 40.71606998
# Iter 176 Primal Discrepancies 0.00011630 R value 40.71606982
# Iter 177 Primal Discrepancies 0.00010642 R value 40.71606857
# Iter 178 Primal Discrepancies 0.00008896 R value 40.71606646
# Iter 179 Primal Discrepancies 0.00006631 R value 40.71606377
# Iter 180 Primal Discrepancies 0.00004098 R value 40.71606080
# Iter 181 Primal Discrepancies 0.00001540 R value 40.71605783
# Iter 182 Primal Discrepancies 0.00000853 R value 40.71605510
# Iter 183 Primal Discrepancies 0.00002836 R value 40.71605281
# Iter 184 Primal Discrepancies 0.00004359 R value 40.71605109
# Iter 185 Primal Discrepancies 0.00005334 R value 40.71605002
# Iter 186 Primal Discrepancies 0.00005747 R value 40.71604961
# Iter 187 Primal Discrepancies 0.00005633 R value 40.71604980
# Iter 188 Primal Discrepancies 0.00005068 R value 40.71605051
# Iter 189 Primal Discrepancies 0.00004153 R value 40.71605161
# Iter 190 Primal Discrepancies 0.00003009 R value 40.71605296
# Iter 191 Primal Discrepancies 0.00001757 R value 40.71605443
# Iter 192 Primal Discrepancies 0.00000531 R value 40.71605587
# Iter 193 Primal Discrepancies 0.00000616 R value 40.71605717
# Iter 194 Primal Discrepancies 0.00001556 R value 40.71605824
# Iter 195 Primal Discrepancies 0.00002250 R value 40.71605902
# Iter 196 Primal Discrepancies 0.00002673 R value 40.71605948
# Iter 197 Primal Discrepancies 0.00002822 R value 40.71605962
# Iter 198 Primal Discrepancies 0.00002720 R value 40.71605947
# Iter 199 Primal Discrepancies 0.00002405 R value 40.71605908
# Iter 200 Primal Discrepancies 0.00001930 R value 40.71605851
# Iter 201 Primal Discrepancies 0.00001354 R value 40.71605783
# Iter 202 Primal Discrepancies 0.00000738 R value 40.71605711
# Iter 203 Primal Discrepancies 0.00000175 R value 40.71605642
# Iter 204 Primal Discrepancies 0.00000401 R value 40.71605580
# Iter 205 Primal Discrepancies 0.00000839 R value 40.71605530
# Iter 206 Primal Discrepancies 0.00001153 R value 40.71605495
# Iter 207 Primal Discrepancies 0.00001334 R value 40.71605476
# Iter 208 Primal Discrepancies 0.00001381 R value 40.71605472
# Iter 209 Primal Discrepancies 0.00001309 R value 40.71605482
# Iter 210 Primal Discrepancies 0.00001137 R value 40.71605503
# Iter 211 Primal Discrepancies 0.00000892 R value 40.71605532
# Iter 212 Primal Discrepancies 0.00000604 R value 40.71605566
# Iter 213 Primal Discrepancies 0.00000302 R value 40.71605601
# Iter 214 Primal Discrepancies 0.00000048 R value 40.71605635
# Iter 215 Primal Discrepancies 0.00000243 R value 40.71605664
# Iter 216 Primal Discrepancies 0.00000446 R value 40.71605687
# Iter 217 Primal Discrepancies 0.00000587 R value 40.71605702
# Iter 218 Primal Discrepancies 0.00000663 R value 40.71605710
# Iter 219 Primal Discrepancies 0.00000674 R value 40.71605711
# Iter 220 Primal Discrepancies 0.00000628 R value 40.71605705
# Iter 221 Primal Discrepancies 0.00000535 R value 40.71605694
# Iter 222 Primal Discrepancies 0.00000410 R value 40.71605679
# Iter 223 Primal Discrepancies 0.00000267 R value 40.71605662
# Iter 224 Primal Discrepancies 0.00000119 R value 40.71605645
# Iter 225 Primal Discrepancies 0.00000028 R value 40.71605629
# Iter 226 Primal Discrepancies 0.00000141 R value 40.71605615
# Iter 227 Primal Discrepancies 0.00000235 R value 40.71605604
# Iter 228 Primal Discrepancies 0.00000297 R value 40.71605597
# Iter 229 Primal Discrepancies 0.00000328 R value 40.71605594
# Iter 230 Primal Discrepancies 0.00000327 R value 40.71605595
# Iter 231 Primal Discrepancies 0.00000300 R value 40.71605598
# Iter 232 Primal Discrepancies 0.00000251 R value 40.71605604
# Iter 233 Primal Discrepancies 0.00000188 R value 40.71605612
# Iter 234 Primal Discrepancies 0.00000116 R value 40.71605620
# Iter 235 Primal Discrepancies 0.00000044 R value 40.71605628
# Iter 236 Primal Discrepancies 0.00000023 R value 40.71605636
# Iter 237 Primal Discrepancies 0.00000079 R value 40.71605642
# Iter 238 Primal Discrepancies 0.00000122 R value 40.71605647
# Iter 239 Primal Discrepancies 0.00000150 R value 40.71605650
# Iter 240 Primal Discrepancies 0.00000162 R value 40.71605652
# Iter 241 Primal Discrepancies 0.00000159 R value 40.71605651
# Iter 242 Primal Discrepancies 0.00000143 R value 40.71605649
# Iter 243 Primal Discrepancies 0.00000117 R value 40.71605646
# Iter 244 Primal Discrepancies 0.00000085 R value 40.71605642
# Iter 245 Primal Discrepancies 0.00000050 R value 40.71605638
# Iter 246 Primal Discrepancies 0.00000015 R value 40.71605634
# Iter 247 Primal Discrepancies 0.00000017 R value 40.71605630
# Iter 248 Primal Discrepancies 0.00000043 R value 40.71605627
# Iter 249 Primal Discrepancies 0.00000063 R value 40.71605625
# Iter 250 Primal Discrepancies 0.00000075 R value 40.71605624
# Iter 251 Primal Discrepancies 0.00000079 R value 40.71605623
# Iter 252 Primal Discrepancies 0.00000077 R value 40.71605624
# Iter 253 Primal Discrepancies 0.00000068 R value 40.71605625
# Iter 254 Primal Discrepancies 0.00000055 R value 40.71605626
# Iter 255 Primal Discrepancies 0.00000038 R value 40.71605628
# Iter 256 Primal Discrepancies 0.00000021 R value 40.71605630
# Iter 257 Primal Discrepancies 0.00000005 R value 40.71605632
# Iter 258 Primal Discrepancies 0.00000011 R value 40.71605634
# Iter 259 Primal Discrepancies 0.00000023 R value 40.71605636
# Iter 260 Primal Discrepancies 0.00000032 R value 40.71605637
# Iter 261 Primal Discrepancies 0.00000037 R value 40.71605637
# Iter 262 Primal Discrepancies 0.00000039 R value 40.71605637
# Iter 263 Primal Discrepancies 0.00000037 R value 40.71605637
# Iter 264 Primal Discrepancies 0.00000032 R value 40.71605636
# Iter 265 Primal Discrepancies 0.00000025 R value 40.71605636
# Iter 266 Primal Discrepancies 0.00000017 R value 40.71605635
# Iter 267 Primal Discrepancies 0.00000009 R value 40.71605634
# Iter 268 Primal Discrepancies 0.00000001 R value 40.71605633
# Stopping at iteration 268
# X = 26.500386247095776
# Y = 27.86935954345628
# R = 40.716056326347164
# Correct values are:
# X = 26.50038624217553
# Y = 27.86935953170211
# R = 40.71605633426372

# %%
##QP_ADMM for 4 selected circles in n=20, m=100 test case

using JuMP
using Printf
import Juniper
import Ipopt

a = [31.638687927784943,1.6854696772411517, 34.96903642134066, 7.147231577211446] # x-cordinates of selected circle
b = [17.17851430439765, 2.8765182589078004, 39.17787190718997, 33.785980366613536] # y-cordinates of selected circle
r = [20, 20, 20, 20 ] # Radius of selected circles
   
NumVar = size(r)[1] 

rho = 1.0  ### Augmented Lagrangian penalty coefficient
  ## Note: rho may be allowed to vary under restriction


## Typing of parameters is optional, but wise.
## Form the AL primal subproblem
function solveSP(i::Int64, vdual::Dict{String,Float64}, X::Float64,Y::Float64, R::Float64 )

  model = Model(
        optimizer_with_attributes(
            #Juniper.Optimizer,
            #"nl_solver" => optimizer_with_attributes(
                Ipopt.Optimizer, 
            #    MOI.Silent() => true,
            #),
        ),
    )
    set_optimizer_attribute(model, "print_level", 0)  ### Suppress Ipopt output
    set_optimizer_attribute(model, "tol", 1e-14)  ### Not required in general

    @variable(model, x )
    @variable(model, y )
    @variable(model, z >= 0)
  
    ### primal objective + Lagrange terms + augmented (squared penalty) terms
    @objective(model, Min, z+r[i] 
	+ vdual["x"]*(x + X - a[i]) + vdual["y"]*(y + Y - b[i]) + vdual["z"]*(z + r[i] - R)
	+ 0.5*rho*( (x+X-a[i])^2 + (y+Y-b[i])^2 + (z+r[i]-R)^2 ) )

    ### All coupling constraints are relaxed.
    @constraint( model, xyz, x^2 + y^2 <= z^2)
  
    #@show model
    
    #print(model)
    optimize!(model)

    return value(x), value(y), value(z)
end

function main()
  ## Initialization
    x = Dict{Int64,Float64}()
    y = Dict{Int64,Float64}()
    z = Dict{Int64,Float64}()

    ### Initialize Lagrangian multipliers to zero value
    vdual = Dict{Int64, Dict{String,Float64}}()
    for i in 1:NumVar
	vdual[i] = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    end

    X,Y,R=0.0,0.0,0.0
    oldX,oldY,oldR=0.0,0.0,0.0
    ### Initialize R to average of r[i], i=1,...,n
    for i in 1:length(a)
	R += (1.0/NumVar)*(r[i])
    end
  ## End of initialization

for n in 1:1000
    ### Solve AL subproblem for each subproblem i with X,Y,R fixed
    for i in 1:NumVar
      x[i],y[i],z[i] = solveSP(i,vdual[i],X,Y,R)
    end

    ### Subproblems in X,Y,R (with x,y,z fixed) can be solved in closed-form
    oldX,oldY,oldR=X,Y,R
    X,Y,R=0.0,0.0,0.0
    for i in 1:NumVar
	X += (1.0/NumVar)*(a[i]-x[i])
	Y += (1.0/NumVar)*(b[i]-y[i])
	R += (1.0/NumVar)*(z[i]+r[i])
    end

    ### Update Lagrange multipliers, compute a measure of primal infeasibility.
    discr = Dict("x"=>0.0,"y"=>0.0,"z"=>0.0)
    for i in 1:NumVar
	vdual[i]["x"] += rho*(x[i] + X - a[i]) 
	vdual[i]["y"] += rho*(y[i] + Y - b[i]) 
	vdual[i]["z"] += rho*(z[i] + r[i] - R)

	discr["x"] += abs(x[i] + X - a[i])
	discr["y"] += abs(y[i] + Y - b[i])
	discr["z"] += abs(z[i] + r[i] - R)
    end
    @printf("Iter %d Primal Discrepancies %8.8f R value %8.8f\n", 
	n, discr["x"] + discr["y"] + discr["z"], R)
    d_discr = abs(X-oldX)+abs(Y-oldY)+abs(R-oldR) ### Dual residues
    if discr["x"] + discr["y"] + discr["z"] + d_discr < 1e-7
	println("Stopping at iteration ",n)  ### Primal feasible within tolerance
	break
    end
end
    @show(X)
    @show(Y)
    @show(R)

println("Correct values are: ")

println("X = ",18.327253047203637)
println("Y = ",21.027195084962255)
println("R = ",44.62510960814807)
end

main()
# Out:
# Iter 1 Primal Discrepancies 84.21212302 R value 35.29791321
# Iter 2 Primal Discrepancies 36.65309228 R value 43.88488364
# Iter 3 Primal Discrepancies 36.43178281 R value 47.02848524
# Iter 4 Primal Discrepancies 17.02880228 R value 48.99661811
# Iter 5 Primal Discrepancies 21.70395209 R value 49.46616211
# Iter 6 Primal Discrepancies 19.75454231 R value 48.60838825
# Iter 7 Primal Discrepancies 2.47388693 R value 47.79193763
# Iter 8 Primal Discrepancies 2.71413473 R value 47.16301155
# Iter 9 Primal Discrepancies 2.50210965 R value 46.70696038
# Iter 10 Primal Discrepancies 1.71755874 R value 46.36957820
# Iter 11 Primal Discrepancies 0.69975570 R value 46.08054330
# Iter 12 Primal Discrepancies 0.23853551 R value 45.77502759
# Iter 13 Primal Discrepancies 0.88262004 R value 45.40853020
# Iter 14 Primal Discrepancies 1.14502843 R value 44.96292089
# Iter 15 Primal Discrepancies 1.72475055 R value 44.54451277
# Iter 16 Primal Discrepancies 2.49358524 R value 44.25109528
# Iter 17 Primal Discrepancies 2.69801978 R value 44.12475940
# Iter 18 Primal Discrepancies 2.17684022 R value 44.15530059
# Iter 19 Primal Discrepancies 1.24174600 R value 44.29584547
# Iter 20 Primal Discrepancies 0.51173196 R value 44.48373906
# Iter 21 Primal Discrepancies 0.72769209 R value 44.66015492
# Iter 22 Primal Discrepancies 1.05195832 R value 44.78384500
# Iter 23 Primal Discrepancies 1.13819606 R value 44.83705691
# Iter 24 Primal Discrepancies 0.91832293 R value 44.82409765
# Iter 25 Primal Discrepancies 0.52383790 R value 44.76474149
# Iter 26 Primal Discrepancies 0.21573857 R value 44.68541913
# Iter 27 Primal Discrepancies 0.30690742 R value 44.61094559
# Iter 28 Primal Discrepancies 0.44378610 R value 44.55872018
# Iter 29 Primal Discrepancies 0.48016457 R value 44.53623060
# Iter 30 Primal Discrepancies 0.38740619 R value 44.54165892
# Iter 31 Primal Discrepancies 0.22098524 R value 44.56666258
# Iter 32 Primal Discrepancies 0.09107371 R value 44.60009125
# Iter 33 Primal Discrepancies 0.12953551 R value 44.63147639
# Iter 34 Primal Discrepancies 0.18722520 R value 44.65347795
# Iter 35 Primal Discrepancies 0.20257259 R value 44.66293722
# Iter 36 Primal Discrepancies 0.16344142 R value 44.66062113
# Iter 37 Primal Discrepancies 0.09323446 R value 44.65004904
# Iter 38 Primal Discrepancies 0.03836866 R value 44.63592475
# Iter 39 Primal Discrepancies 0.05459721 R value 44.62266440
# Iter 40 Primal Discrepancies 0.07897485 R value 44.61336430
# Iter 41 Primal Discrepancies 0.08544920 R value 44.60935685
# Iter 42 Primal Discrepancies 0.06894088 R value 44.61031833
# Iter 43 Primal Discrepancies 0.03932273 R value 44.61476392
# Iter 44 Primal Discrepancies 0.01622167 R value 44.62070913
# Iter 45 Primal Discrepancies 0.02307259 R value 44.62629085
# Iter 46 Primal Discrepancies 0.03332706 R value 44.63020279
# Iter 47 Primal Discrepancies 0.03605839 R value 44.63188279
# Iter 48 Primal Discrepancies 0.02909402 R value 44.63146735
# Iter 49 Primal Discrepancies 0.01659898 R value 44.62958283
# Iter 50 Primal Discrepancies 0.00681760 R value 44.62706637
# Iter 51 Primal Discrepancies 0.00970210 R value 44.62470391
# Iter 52 Primal Discrepancies 0.01405007 R value 44.62304648
# Iter 53 Primal Discrepancies 0.01520249 R value 44.62233119
# Iter 54 Primal Discrepancies 0.01226460 R value 44.62250040
# Iter 55 Primal Discrepancies 0.00699349 R value 44.62328985
# Iter 56 Primal Discrepancies 0.00289494 R value 44.62434631
# Iter 57 Primal Discrepancies 0.00411811 R value 44.62533820
# Iter 58 Primal Discrepancies 0.00595246 R value 44.62603302
# Iter 59 Primal Discrepancies 0.00642188 R value 44.62633072
# Iter 60 Primal Discrepancies 0.00518228 R value 44.62625557
# Iter 61 Primal Discrepancies 0.00295836 R value 44.62591906
# Iter 62 Primal Discrepancies 0.00124918 R value 44.62547016
# Iter 63 Primal Discrepancies 0.00171745 R value 44.62504876
# Iter 64 Primal Discrepancies 0.00253020 R value 44.62475290
# Iter 65 Primal Discrepancies 0.00270200 R value 44.62462480
# Iter 66 Primal Discrepancies 0.00217925 R value 44.62465417
# Iter 67 Primal Discrepancies 0.00124124 R value 44.62479399
# Iter 68 Primal Discrepancies 0.00058218 R value 44.62498138
# Iter 69 Primal Discrepancies 0.00074027 R value 44.62515733
# Iter 70 Primal Discrepancies 0.00110579 R value 44.62528046
# Iter 71 Primal Discrepancies 0.00114594 R value 44.62533294
# Iter 72 Primal Discrepancies 0.00092522 R value 44.62531911
# Iter 73 Primal Discrepancies 0.00055438 R value 44.62525879
# Iter 74 Primal Discrepancies 0.00029259 R value 44.62517850
# Iter 75 Primal Discrepancies 0.00033621 R value 44.62510314
# Iter 76 Primal Discrepancies 0.00047866 R value 44.62505015
# Iter 77 Primal Discrepancies 0.00048691 R value 44.62502704
# Iter 78 Primal Discrepancies 0.00040406 R value 44.62503198
# Iter 79 Primal Discrepancies 0.00027456 R value 44.62505660
# Iter 80 Primal Discrepancies 0.00018826 R value 44.62508971
# Iter 81 Primal Discrepancies 0.00020212 R value 44.62512080
# Iter 82 Primal Discrepancies 0.00024411 R value 44.62514251
# Iter 83 Primal Discrepancies 0.00024877 R value 44.62515166
# Iter 84 Primal Discrepancies 0.00021532 R value 44.62514902
# Iter 85 Primal Discrepancies 0.00016067 R value 44.62513812
# Iter 86 Primal Discrepancies 0.00013669 R value 44.62512368
# Iter 87 Primal Discrepancies 0.00014250 R value 44.62511013
# Iter 88 Primal Discrepancies 0.00015115 R value 44.62510057
# Iter 89 Primal Discrepancies 0.00014709 R value 44.62509634
# Iter 90 Primal Discrepancies 0.00013345 R value 44.62509711
# Iter 91 Primal Discrepancies 0.00011501 R value 44.62510139
# Iter 92 Primal Discrepancies 0.00010209 R value 44.62510719
# Iter 93 Primal Discrepancies 0.00010183 R value 44.62511264
# Iter 94 Primal Discrepancies 0.00010347 R value 44.62511642
# Iter 95 Primal Discrepancies 0.00010026 R value 44.62511797
# Iter 96 Primal Discrepancies 0.00009339 R value 44.62511744
# Iter 97 Primal Discrepancies 0.00008467 R value 44.62511543
# Iter 98 Primal Discrepancies 0.00007828 R value 44.62511281
# Iter 99 Primal Discrepancies 0.00007723 R value 44.62511034
# Iter 100 Primal Discrepancies 0.00007674 R value 44.62510859
# Iter 101 Primal Discrepancies 0.00007407 R value 44.62510779
# Iter 102 Primal Discrepancies 0.00006977 R value 44.62510789
# Iter 103 Primal Discrepancies 0.00006469 R value 44.62510861
# Iter 104 Primal Discrepancies 0.00006067 R value 44.62510961
# Iter 105 Primal Discrepancies 0.00005894 R value 44.62511054
# Iter 106 Primal Discrepancies 0.00005764 R value 44.62511118
# Iter 107 Primal Discrepancies 0.00005554 R value 44.62511143
# Iter 108 Primal Discrepancies 0.00005284 R value 44.62511131
# Iter 109 Primal Discrepancies 0.00004987 R value 44.62511093
# Iter 110 Primal Discrepancies 0.00004737 R value 44.62511044
# Iter 111 Primal Discrepancies 0.00004589 R value 44.62510998
# Iter 112 Primal Discrepancies 0.00004454 R value 44.62510965
# Iter 113 Primal Discrepancies 0.00004286 R value 44.62510949
# Iter 114 Primal Discrepancies 0.00004094 R value 44.62510949
# Iter 115 Primal Discrepancies 0.00003892 R value 44.62510961
# Iter 116 Primal Discrepancies 0.00003713 R value 44.62510977
# Iter 117 Primal Discrepancies 0.00003579 R value 44.62510992
# Iter 118 Primal Discrepancies 0.00003457 R value 44.62511003
# Iter 119 Primal Discrepancies 0.00003324 R value 44.62511006
# Iter 120 Primal Discrepancies 0.00003185 R value 44.62511003
# Iter 121 Primal Discrepancies 0.00003045 R value 44.62510995
# Iter 122 Primal Discrepancies 0.00002916 R value 44.62510986
# Iter 123 Primal Discrepancies 0.00002809 R value 44.62510977
# Iter 124 Primal Discrepancies 0.00002707 R value 44.62510970
# Iter 125 Primal Discrepancies 0.00002602 R value 44.62510966
# Iter 126 Primal Discrepancies 0.00002496 R value 44.62510966
# Iter 127 Primal Discrepancies 0.00002391 R value 44.62510967
# Iter 128 Primal Discrepancies 0.00002293 R value 44.62510970
# Iter 129 Primal Discrepancies 0.00002205 R value 44.62510972
# Iter 130 Primal Discrepancies 0.00002122 R value 44.62510973
# Iter 131 Primal Discrepancies 0.00002039 R value 44.62510973
# Iter 132 Primal Discrepancies 0.00001958 R value 44.62510973
# Iter 133 Primal Discrepancies 0.00001879 R value 44.62510971
# Iter 134 Primal Discrepancies 0.00001803 R value 44.62510969
# Iter 135 Primal Discrepancies 0.00001734 R value 44.62510967
# Iter 136 Primal Discrepancies 0.00001668 R value 44.62510965
# Iter 137 Primal Discrepancies 0.00001603 R value 44.62510965
# Iter 138 Primal Discrepancies 0.00001540 R value 44.62510964
# Iter 139 Primal Discrepancies 0.00001478 R value 44.62510964
# Iter 140 Primal Discrepancies 0.00001419 R value 44.62510964
# Iter 141 Primal Discrepancies 0.00001364 R value 44.62510965
# Iter 142 Primal Discrepancies 0.00001311 R value 44.62510965
# Iter 143 Primal Discrepancies 0.00001260 R value 44.62510965
# Iter 144 Primal Discrepancies 0.00001211 R value 44.62510964
# Iter 145 Primal Discrepancies 0.00001163 R value 44.62510964
# Iter 146 Primal Discrepancies 0.00001117 R value 44.62510963
# Iter 147 Primal Discrepancies 0.00001074 R value 44.62510963
# Iter 148 Primal Discrepancies 0.00001032 R value 44.62510963
# Iter 149 Primal Discrepancies 0.00000992 R value 44.62510962
# Iter 150 Primal Discrepancies 0.00000953 R value 44.62510962
# Iter 151 Primal Discrepancies 0.00000915 R value 44.62510962
# Iter 152 Primal Discrepancies 0.00000879 R value 44.62510962
# Iter 153 Primal Discrepancies 0.00000845 R value 44.62510962
# Iter 154 Primal Discrepancies 0.00000812 R value 44.62510962
# Iter 155 Primal Discrepancies 0.00000780 R value 44.62510962
# Iter 156 Primal Discrepancies 0.00000750 R value 44.62510962
# Iter 157 Primal Discrepancies 0.00000720 R value 44.62510962
# Iter 158 Primal Discrepancies 0.00000692 R value 44.62510961
# Iter 159 Primal Discrepancies 0.00000665 R value 44.62510961
# Iter 160 Primal Discrepancies 0.00000639 R value 44.62510961
# Iter 161 Primal Discrepancies 0.00000614 R value 44.62510961
# Iter 162 Primal Discrepancies 0.00000590 R value 44.62510961
# Iter 163 Primal Discrepancies 0.00000567 R value 44.62510961
# Iter 164 Primal Discrepancies 0.00000545 R value 44.62510961
# Iter 165 Primal Discrepancies 0.00000524 R value 44.62510961
# Iter 166 Primal Discrepancies 0.00000503 R value 44.62510961
# Iter 167 Primal Discrepancies 0.00000484 R value 44.62510961
# Iter 168 Primal Discrepancies 0.00000465 R value 44.62510961
# Iter 169 Primal Discrepancies 0.00000446 R value 44.62510961
# Iter 170 Primal Discrepancies 0.00000429 R value 44.62510961
# Iter 171 Primal Discrepancies 0.00000412 R value 44.62510961
# Iter 172 Primal Discrepancies 0.00000396 R value 44.62510961
# Iter 173 Primal Discrepancies 0.00000381 R value 44.62510961
# Iter 174 Primal Discrepancies 0.00000366 R value 44.62510961
# Iter 175 Primal Discrepancies 0.00000351 R value 44.62510961
# Iter 176 Primal Discrepancies 0.00000338 R value 44.62510961
# Iter 177 Primal Discrepancies 0.00000325 R value 44.62510961
# Iter 178 Primal Discrepancies 0.00000312 R value 44.62510961
# Iter 179 Primal Discrepancies 0.00000300 R value 44.62510961
# Iter 180 Primal Discrepancies 0.00000288 R value 44.62510961
# Iter 181 Primal Discrepancies 0.00000277 R value 44.62510960
# Iter 182 Primal Discrepancies 0.00000266 R value 44.62510960
# Iter 183 Primal Discrepancies 0.00000255 R value 44.62510960
# Iter 184 Primal Discrepancies 0.00000245 R value 44.62510960
# Iter 185 Primal Discrepancies 0.00000236 R value 44.62510960
# Iter 186 Primal Discrepancies 0.00000227 R value 44.62510960
# Iter 187 Primal Discrepancies 0.00000218 R value 44.62510960
# Iter 188 Primal Discrepancies 0.00000209 R value 44.62510960
# Iter 189 Primal Discrepancies 0.00000201 R value 44.62510960
# Iter 190 Primal Discrepancies 0.00000193 R value 44.62510960
# Iter 191 Primal Discrepancies 0.00000186 R value 44.62510960
# Iter 192 Primal Discrepancies 0.00000178 R value 44.62510960
# Iter 193 Primal Discrepancies 0.00000171 R value 44.62510960
# Iter 194 Primal Discrepancies 0.00000165 R value 44.62510960
# Iter 195 Primal Discrepancies 0.00000158 R value 44.62510960
# Iter 196 Primal Discrepancies 0.00000152 R value 44.62510960
# Iter 197 Primal Discrepancies 0.00000146 R value 44.62510960
# Iter 198 Primal Discrepancies 0.00000140 R value 44.62510960
# Iter 199 Primal Discrepancies 0.00000135 R value 44.62510960
# Iter 200 Primal Discrepancies 0.00000130 R value 44.62510960
# Iter 201 Primal Discrepancies 0.00000125 R value 44.62510960
# Iter 202 Primal Discrepancies 0.00000120 R value 44.62510960
# Iter 203 Primal Discrepancies 0.00000115 R value 44.62510960
# Iter 204 Primal Discrepancies 0.00000111 R value 44.62510960
# Iter 205 Primal Discrepancies 0.00000106 R value 44.62510960
# Iter 206 Primal Discrepancies 0.00000102 R value 44.62510960
# Iter 207 Primal Discrepancies 0.00000098 R value 44.62510960
# Iter 208 Primal Discrepancies 0.00000094 R value 44.62510960
# Iter 209 Primal Discrepancies 0.00000091 R value 44.62510960
# Iter 210 Primal Discrepancies 0.00000087 R value 44.62510960
# Iter 211 Primal Discrepancies 0.00000084 R value 44.62510960
# Iter 212 Primal Discrepancies 0.00000080 R value 44.62510960
# Iter 213 Primal Discrepancies 0.00000077 R value 44.62510960
# Iter 214 Primal Discrepancies 0.00000074 R value 44.62510960
# Iter 215 Primal Discrepancies 0.00000071 R value 44.62510960
# Iter 216 Primal Discrepancies 0.00000069 R value 44.62510960
# Iter 217 Primal Discrepancies 0.00000066 R value 44.62510960
# Iter 218 Primal Discrepancies 0.00000063 R value 44.62510960
# Iter 219 Primal Discrepancies 0.00000061 R value 44.62510960
# Iter 220 Primal Discrepancies 0.00000058 R value 44.62510960
# Iter 221 Primal Discrepancies 0.00000056 R value 44.62510960
# Iter 222 Primal Discrepancies 0.00000054 R value 44.62510960
# Iter 223 Primal Discrepancies 0.00000052 R value 44.62510960
# Iter 224 Primal Discrepancies 0.00000050 R value 44.62510960
# Iter 225 Primal Discrepancies 0.00000048 R value 44.62510960
# Iter 226 Primal Discrepancies 0.00000046 R value 44.62510960
# Iter 227 Primal Discrepancies 0.00000044 R value 44.62510960
# Iter 228 Primal Discrepancies 0.00000042 R value 44.62510960
# Iter 229 Primal Discrepancies 0.00000041 R value 44.62510960
# Iter 230 Primal Discrepancies 0.00000039 R value 44.62510960
# Iter 231 Primal Discrepancies 0.00000038 R value 44.62510960
# Iter 232 Primal Discrepancies 0.00000036 R value 44.62510960
# Iter 233 Primal Discrepancies 0.00000035 R value 44.62510960
# Iter 234 Primal Discrepancies 0.00000033 R value 44.62510960
# Iter 235 Primal Discrepancies 0.00000032 R value 44.62510960
# Iter 236 Primal Discrepancies 0.00000031 R value 44.62510960
# Iter 237 Primal Discrepancies 0.00000030 R value 44.62510960
# Iter 238 Primal Discrepancies 0.00000029 R value 44.62510960
# Iter 239 Primal Discrepancies 0.00000027 R value 44.62510960
# Iter 240 Primal Discrepancies 0.00000026 R value 44.62510960
# Iter 241 Primal Discrepancies 0.00000025 R value 44.62510960
# Iter 242 Primal Discrepancies 0.00000024 R value 44.62510960
# Iter 243 Primal Discrepancies 0.00000023 R value 44.62510960
# Iter 244 Primal Discrepancies 0.00000022 R value 44.62510960
# Iter 245 Primal Discrepancies 0.00000022 R value 44.62510960
# Iter 246 Primal Discrepancies 0.00000021 R value 44.62510960
# Iter 247 Primal Discrepancies 0.00000020 R value 44.62510960
# Iter 248 Primal Discrepancies 0.00000019 R value 44.62510960
# Iter 249 Primal Discrepancies 0.00000018 R value 44.62510960
# Iter 250 Primal Discrepancies 0.00000018 R value 44.62510960
# Iter 251 Primal Discrepancies 0.00000017 R value 44.62510960
# Iter 252 Primal Discrepancies 0.00000016 R value 44.62510960
# Iter 253 Primal Discrepancies 0.00000016 R value 44.62510960
# Iter 254 Primal Discrepancies 0.00000015 R value 44.62510960
# Iter 255 Primal Discrepancies 0.00000014 R value 44.62510960
# Iter 256 Primal Discrepancies 0.00000014 R value 44.62510960
# Iter 257 Primal Discrepancies 0.00000013 R value 44.62510960
# Iter 258 Primal Discrepancies 0.00000013 R value 44.62510960
# Iter 259 Primal Discrepancies 0.00000012 R value 44.62510960
# Iter 260 Primal Discrepancies 0.00000012 R value 44.62510960
# Iter 261 Primal Discrepancies 0.00000011 R value 44.62510960
# Iter 262 Primal Discrepancies 0.00000011 R value 44.62510960
# Iter 263 Primal Discrepancies 0.00000011 R value 44.62510960
# Iter 264 Primal Discrepancies 0.00000010 R value 44.62510960
# Iter 265 Primal Discrepancies 0.00000010 R value 44.62510960
# Iter 266 Primal Discrepancies 0.00000009 R value 44.62510960
# Iter 267 Primal Discrepancies 0.00000009 R value 44.62510960
# Iter 268 Primal Discrepancies 0.00000009 R value 44.62510960
# Iter 269 Primal Discrepancies 0.00000008 R value 44.62510960
# Iter 270 Primal Discrepancies 0.00000008 R value 44.62510960
# Iter 271 Primal Discrepancies 0.00000008 R value 44.62510960
# Iter 272 Primal Discrepancies 0.00000007 R value 44.62510960
# Iter 273 Primal Discrepancies 0.00000007 R value 44.62510960
# Iter 274 Primal Discrepancies 0.00000007 R value 44.62510960
# Iter 275 Primal Discrepancies 0.00000007 R value 44.62510960
# Iter 276 Primal Discrepancies 0.00000006 R value 44.62510960
# Iter 277 Primal Discrepancies 0.00000006 R value 44.62510960
# Iter 278 Primal Discrepancies 0.00000006 R value 44.62510960
# Iter 279 Primal Discrepancies 0.00000006 R value 44.62510960
# Iter 280 Primal Discrepancies 0.00000005 R value 44.62510960
# Iter 281 Primal Discrepancies 0.00000005 R value 44.62510960
# Iter 282 Primal Discrepancies 0.00000005 R value 44.62510960
# Iter 283 Primal Discrepancies 0.00000005 R value 44.62510960
# Iter 284 Primal Discrepancies 0.00000005 R value 44.62510960
# Iter 285 Primal Discrepancies 0.00000004 R value 44.62510960
# Iter 286 Primal Discrepancies 0.00000004 R value 44.62510960
# Iter 287 Primal Discrepancies 0.00000004 R value 44.62510960
# Iter 288 Primal Discrepancies 0.00000004 R value 44.62510960
# Iter 289 Primal Discrepancies 0.00000004 R value 44.62510960
# Iter 290 Primal Discrepancies 0.00000004 R value 44.62510960
# Iter 291 Primal Discrepancies 0.00000003 R value 44.62510960
# Iter 292 Primal Discrepancies 0.00000003 R value 44.62510960
# Iter 293 Primal Discrepancies 0.00000003 R value 44.62510960
# Iter 294 Primal Discrepancies 0.00000003 R value 44.62510960
# Iter 295 Primal Discrepancies 0.00000003 R value 44.62510960
# Iter 296 Primal Discrepancies 0.00000003 R value 44.62510960
# Iter 297 Primal Discrepancies 0.00000003 R value 44.62510960
# Iter 298 Primal Discrepancies 0.00000003 R value 44.62510960
# Iter 299 Primal Discrepancies 0.00000003 R value 44.62510960
# Iter 300 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 301 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 302 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 303 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 304 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 305 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 306 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 307 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 308 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 309 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 310 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 311 Primal Discrepancies 0.00000002 R value 44.62510960
# Iter 312 Primal Discrepancies 0.00000001 R value 44.62510960
# Iter 313 Primal Discrepancies 0.00000001 R value 44.62510960
# Iter 314 Primal Discrepancies 0.00000001 R value 44.62510960
# Stopping at iteration 314
# X = 18.327251963724535
# Y = 21.027196078370466
# R = 44.625109603139755
# Correct values are:
# X = 18.327253047203637
# Y = 21.027195084962255
# R = 44.62510960814807
